# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('https://raw.githubusercontent.com/FlipRoboTechnologies/ML-Datasets/main/Bank%20Marketing/termdeposit_train.csv')
df
# Out:
#           ID  age         job   marital  education default  balance housing  \
# 0      26110   56      admin.   married    unknown      no     1933      no
# 1      40576   31     unknown   married  secondary      no        3      no
# 2      15320   27    services   married  secondary      no      891     yes
# 3      43962   57  management  divorced   tertiary      no     3287      no
# 4      29842   31  technician   married  secondary      no      119     yes
# ...      ...  ...         ...       ...        ...     ...      ...     ...
# 31642  36483   29  management    single   tertiary      no        0     yes
# 31643  40178   53  management  divorced   tertiary      no      380      no
# 31644  19710   32  management    single   tertiary      no      312      no
# 31645  38556   57  technician   married  secondary      no      225     yes
# 31646  14156   55  management  divorced  secondary      no      204     yes
#
#       loan    contact  day month  duration  campaign  pdays  previous  \
# 0       no  telephone   19   nov        44         2     -1         0
# 1       no   cellular   20   jul        91         2     -1         0
# 2       no   cellular   18   jul       240         1     -1         0
# 3       no   cellular   22   jun       867         1     84         3
# 4       no   cellular    4   feb       380         1     -1         0
# ...    ...        ...  ...   ...       ...       ...    ...       ...
# 31642   no   cellular   12   may       116         2     -1         0
# 31643  yes   cellular    5   jun       438         2     -1         0
# 31644   no   cellular    7   aug        37         3     -1         0
# 31645   no  telephone   15   may        22         7    337        12
# 31646   no   cellular   11   jul      1973         2     -1         0
#
#       poutcome subscribed
# 0      unknown         no
# 1      unknown         no
# 2      unknown         no
# 3      success        yes
# 4      unknown         no
# ...        ...        ...
# 31642  unknown         no
# 31643  unknown        yes
# 31644  unknown         no
# 31645  failure         no
# 31646  unknown        yes
#
# [31647 rows x 18 columns]

# %%
df2=pd.read_csv('https://raw.githubusercontent.com/FlipRoboTechnologies/ML-Datasets/main/Bank%20Marketing/termdeposit_test.csv')
df2
# Out:
#           ID  age            job   marital  education default  balance  \
# 0      38441   32       services   married  secondary      no      118
# 1      40403   78        retired  divorced    primary      no     2787
# 2       3709   31  self-employed    single   tertiary      no      144
# 3      37422   57       services    single    primary      no     3777
# 4      12527   45    blue-collar  divorced  secondary      no     -705
# ...      ...  ...            ...       ...        ...     ...      ...
# 13559  23465   39     management   married   tertiary      no       45
# 13560  11743   54    blue-collar   married    primary      no     2281
# 13561  28292   35        retired   married    primary      no      285
# 13562  45163   29         admin.    single  secondary      no      464
# 13563  34839   29         admin.   married  secondary      no        2
#
#       housing loan    contact  day month  duration  campaign  pdays  previous  \
# 0         yes   no   cellular   15   may        20         6     -1         0
# 1          no   no  telephone    1   jul       372         1     -1         0
# 2         yes   no    unknown   16   may       676         1     -1         0
# 3         yes   no  telephone   13   may        65         2     -1         0
# 4          no  yes    unknown    3   jul       111         1     -1         0
# ...       ...  ...        ...  ...   ...       ...       ...    ...       ...
# 13559      no   no   cellular   28   aug       148         4     -1         0
# 13560     yes   no    unknown   20   jun       158         1     -1         0
# 13561     yes   no   cellular   29   jan       136         1     -1         0
# 13562      no   no   cellular    9   nov       208         2     91         3
# 13563     yes   no   cellular    6   may       339         1    362         1
#
#       poutcome
# 0      unknown
# 1      unknown
# 2      unknown
# 3      unknown
# 4      unknown
# ...        ...
# 13559  unknown
# 13560  unknown
# 13561  unknown
# 13562  success
# 13563  failure
#
# [13564 rows x 17 columns]

# %%
#lets concatenate both the dataset 
df1=df = pd.concat([df,df2])
df1
# Out:
#           ID  age          job   marital  education default  balance housing  \
# 0      26110   56       admin.   married    unknown      no     1933      no
# 1      40576   31      unknown   married  secondary      no        3      no
# 2      15320   27     services   married  secondary      no      891     yes
# 3      43962   57   management  divorced   tertiary      no     3287      no
# 4      29842   31   technician   married  secondary      no      119     yes
# ...      ...  ...          ...       ...        ...     ...      ...     ...
# 13559  23465   39   management   married   tertiary      no       45      no
# 13560  11743   54  blue-collar   married    primary      no     2281     yes
# 13561  28292   35      retired   married    primary      no      285     yes
# 13562  45163   29       admin.    single  secondary      no      464      no
# 13563  34839   29       admin.   married  secondary      no        2     yes
#
#       loan    contact  day month  duration  campaign  pdays  previous  \
# 0       no  telephone   19   nov        44         2     -1         0
# 1       no   cellular   20   jul        91         2     -1         0
# 2       no   cellular   18   jul       240         1     -1         0
# 3       no   cellular   22   jun       867         1     84         3
# 4       no   cellular    4   feb       380         1     -1         0
# ...    ...        ...  ...   ...       ...       ...    ...       ...
# 13559   no   cellular   28   aug       148         4     -1         0
# 13560   no    unknown   20   jun       158         1     -1         0
# 13561   no   cellular   29   jan       136         1     -1         0
# 13562   no   cellular    9   nov       208         2     91         3
# 13563   no   cellular    6   may       339         1    362         1
#
#       poutcome subscribed
# 0      unknown         no
# 1      unknown         no
# 2      unknown         no
# 3      success        yes
# 4      unknown         no
# ...        ...        ...
# 13559  unknown        NaN
# 13560  unknown        NaN
# 13561  unknown        NaN
# 13562  success        NaN
# 13563  failure        NaN
#
# [45211 rows x 18 columns]

# %% [markdown]
# # Exploratory Data Analysis

# %%
df1.head()
# Out:
#       ID  age         job   marital  education default  balance housing loan  \
# 0  26110   56      admin.   married    unknown      no     1933      no   no
# 1  40576   31     unknown   married  secondary      no        3      no   no
# 2  15320   27    services   married  secondary      no      891     yes   no
# 3  43962   57  management  divorced   tertiary      no     3287      no   no
# 4  29842   31  technician   married  secondary      no      119     yes   no
#
#      contact  day month  duration  campaign  pdays  previous poutcome  \
# 0  telephone   19   nov        44         2     -1         0  unknown
# 1   cellular   20   jul        91         2     -1         0  unknown
# 2   cellular   18   jul       240         1     -1         0  unknown
# 3   cellular   22   jun       867         1     84         3  success
# 4   cellular    4   feb       380         1     -1         0  unknown
#
#   subscribed
# 0         no
# 1         no
# 2         no
# 3        yes
# 4         no

# %%
df1.tail()
# Out:
#           ID  age          job  marital  education default  balance housing  \
# 13559  23465   39   management  married   tertiary      no       45      no
# 13560  11743   54  blue-collar  married    primary      no     2281     yes
# 13561  28292   35      retired  married    primary      no      285     yes
# 13562  45163   29       admin.   single  secondary      no      464      no
# 13563  34839   29       admin.  married  secondary      no        2     yes
#
#       loan   contact  day month  duration  campaign  pdays  previous poutcome  \
# 13559   no  cellular   28   aug       148         4     -1         0  unknown
# 13560   no   unknown   20   jun       158         1     -1         0  unknown
# 13561   no  cellular   29   jan       136         1     -1         0  unknown
# 13562   no  cellular    9   nov       208         2     91         3  success
# 13563   no  cellular    6   may       339         1    362         1  failure
#
#       subscribed
# 13559        NaN
# 13560        NaN
# 13561        NaN
# 13562        NaN
# 13563        NaN

# %%
df1.columns
# Out:
# Index(['ID', 'age', 'job', 'marital', 'education', 'default', 'balance',
#        'housing', 'loan', 'contact', 'day', 'month', 'duration', 'campaign',
#        'pdays', 'previous', 'poutcome', 'subscribed'],
#       dtype='object')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45211 entries, 0 to 13563
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          45211 non-null  int64
#  1   age         45211 non-null  int64
#  2   job         45211 non-null  object
#  3   marital     45211 non-null  object
#  4   education   45211 non-null  object
#  5   default     45211 non-null  object
#  6   balance     45211 non-null  int64
#  7   housing     45211 non-null  object
#  8   loan        45211 non-null  object
#  9   contact     45211 non-null  object
#  10  day         45211 non-null  int64
#  11  month       45211 non-null  object
#  12  duration    45211 non-null  int64
#  13  campaign    45211 non-null  int64
#  14  pdays       45211 non-null  int64
#  15  previous    45211 non-null  int64
#  16  poutcome    45211 non-null  object
#  17  subscribed  31647 non-null  object
# dtypes: int64(8), object(10)
# memory usage: 6.6+ MB

# %% [markdown]
# We have 10 object datatypes and 8 int64 dataype and no null values

# %%
df1.info
# Out:
# <bound method DataFrame.info of           ID  age          job   marital  education default  balance housing  \
# 0      26110   56       admin.   married    unknown      no     1933      no
# 1      40576   31      unknown   married  secondary      no        3      no
# 2      15320   27     services   married  secondary      no      891     yes
# 3      43962   57   management  divorced   tertiary      no     3287      no
# 4      29842   31   technician   married  secondary      no      119     yes
# ...      ...  ...          ...       ...        ...     ...      ...     ...
# 13559  23465   39   management   married   tertiary      no       45      no
# 13560  11743   54  blue-collar   married    primary      no     2281     yes
# 13561  28292   35      retired   married    primary      no      285     yes
# 13562  45163   29       admin.    single  secondary      no      464      no
# 13563  34839   29       admin.   married  secondary      no        2     yes
#
#       loan    contact  day month  duration  campaign  pdays  previous  \
# 0       no  telephone   19   nov        44         2     -1         0
# 1       no   cellular   20   jul        91         2     -1         0
# 2       no   cellular   18   jul       240         1     -1         0
# 3       no   cellular   22   jun       867         1     84         3
# 4       no   cellular    4   feb       380         1     -1         0
# ...    ...        ...  ...   ...       ...       ...    ...       ...
# 13559   no   cellular   28   aug       148         4     -1         0
# 13560   no    unknown   20   jun       158         1     -1         0
# 13561   no   cellular   29   jan       136         1     -1         0
# 13562   no   cellular    9   nov       208         2     91         3
# 13563   no   cellular    6   may       339         1    362         1
#
#       poutcome subscribed
# 0      unknown         no
# 1      unknown         no
# 2      unknown         no
# 3      success        yes
# 4      unknown         no
# ...        ...        ...
# 13559  unknown        NaN
# 13560  unknown        NaN
# 13561  unknown        NaN
# 13562  success        NaN
# 13563  failure        NaN
#
# [45211 rows x 18 columns]>

# %%
df1.shape
# Out:
# (45211, 18)

# %%
df1.isnull().sum()
# Out:
# ID                0
# age               0
# job               0
# marital           0
# education         0
# default           0
# balance           0
# housing           0
# loan              0
# contact           0
# day               0
# month             0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# subscribed    13564
# dtype: int64

# %% [markdown]
# we donot find any null values in the data set.Lets find the Heat map as well

# %%
sns.heatmap(df1.isnull()) # we can cleaerly visualize that there is no null value present
# Out:
# <Axes: >

# %% [markdown]
# Hense we can infer that there is no null value in the data set

# %%
df1['subscribed'].unique()
# Out:
# array(['no', 'yes', nan], dtype=object)

# %%
# checking the value counts of each column
for i in df1.columns:
    print (df1[i].value_counts())
    print('\n')
# Out:
# 26110    1
# 18973    1
# 7614     1
# 11057    1
# 12257    1
#         ..
# 6716     1
# 41330    1
# 5765     1
# 8833     1
# 34839    1
# Name: ID, Length: 45211, dtype: int64
#
#
# 32    2085
# 31    1996
# 33    1972
# 34    1930
# 35    1894
#       ...
# 92       2
# 95       2
# 93       2
# 90       2
# 94       1
# Name: age, Length: 77, dtype: int64
#
#
# blue-collar      9732
# management       9458
# technician       7597
# admin.           5171
# services         4154
# retired          2264
# self-employed    1579
# entrepreneur     1487
# unemployed       1303
# housemaid        1240
# student           938
# unknown           288
# Name: job, dtype: int64
#
#
# married     27214
# single      12790
# divorced     5207
# Name: marital, dtype: int64
#
#
# secondary    23202
# tertiary     13301
# primary       6851
# unknown       1857
# Name: education, dtype: int64
#
#
# no     44396
# yes      815
# Name: default, dtype: int64
#
#
#  0        3514
#  1         195
#  2         156
#  4         139
#  3         134
#           ...
#  4244        1
# -1034        1
#  4231        1
#  4808        1
#  17555       1
# Name: balance, Length: 7168, dtype: int64
#
#
# yes    25130
# no     20081
# Name: housing, dtype: int64
#
#
# no     37967
# yes     7244
# Name: loan, dtype: int64
#
#
# cellular     29285
# unknown      13020
# telephone     2906
# Name: contact, dtype: int64
#
#
# 20    2752
# 18    2308
# 21    2026
# 17    1939
# 6     1932
# 5     1910
# 14    1848
# 8     1842
# 28    1830
# 7     1817
# 19    1757
# 29    1745
# 15    1703
# 12    1603
# 13    1585
# 30    1566
# 9     1561
# 11    1479
# 4     1445
# 16    1415
# 2     1293
# 27    1121
# 3     1079
# 26    1035
# 23     939
# 22     905
# 25     840
# 31     643
# 10     524
# 24     447
# 1      322
# Name: day, dtype: int64
#
#
# may    13766
# jul     6895
# aug     6247
# jun     5341
# nov     3970
# apr     2932
# feb     2649
# jan     1403
# oct      738
# sep      579
# mar      477
# dec      214
# Name: month, dtype: int64
#
#
# 124     188
# 90      184
# 89      177
# 104     175
# 114     175
#        ...
# 1545      1
# 1487      1
# 1250      1
# 1112      1
# 1085      1
# Name: duration, Length: 1573, dtype: int64
#
#
# 1     17544
# 2     12505
# 3      5521
# 4      3522
# 5      1764
# 6      1291
# 7       735
# 8       540
# 9       327
# 10      266
# 11      201
# 12      155
# 13      133
# 14       93
# 15       84
# 16       79
# 17       69
# 18       51
# 19       44
# 20       43
# 21       35
# 22       23
# 25       22
# 23       22
# 24       20
# 28       16
# 29       16
# 26       13
# 31       12
# 27       10
# 32        9
# 30        8
# 33        6
# 34        5
# 36        4
# 35        4
# 43        3
# 38        3
# 41        2
# 37        2
# 50        2
# 55        1
# 63        1
# 44        1
# 39        1
# 46        1
# 58        1
# 51        1
# Name: campaign, dtype: int64
#
#
# -1      36954
#  182      167
#  92       147
#  91       126
#  183      126
#         ...
#  26         1
#  761        1
#  404        1
#  586        1
#  680        1
# Name: pdays, Length: 559, dtype: int64
#
#
# 0      36954
# 1       2772
# 2       2106
# 3       1142
# 4        714
# 5        459
# 6        277
# 7        205
# 8        129
# 9         92
# 10        67
# 11        65
# 12        44
# 13        38
# 15        20
# 14        19
# 17        15
# 16        13
# 19        11
# 23         8
# 20         8
# 18         6
# 22         6
# 24         5
# 27         5
# 29         4
# 25         4
# 21         4
# 30         3
# 28         2
# 26         2
# 38         2
# 37         2
# 40         1
# 41         1
# 55         1
# 275        1
# 35         1
# 58         1
# 32         1
# 51         1
# Name: previous, dtype: int64
#
#
# unknown    36959
# failure     4901
# other       1840
# success     1511
# Name: poutcome, dtype: int64
#
#
# no     27932
# yes     3715
# Name: subscribed, dtype: int64

# %% [markdown]
# We have 9 object datatypes and 8 int64 dataype and no null values

# %% [markdown]
# No null values in Test data as well

# %%
# checking the value counts of each column
for i in df2.columns:
    print (df2[i].value_counts())
    print('\n')
# Out:
# 38441    1
# 23664    1
# 23378    1
# 18945    1
# 32574    1
#         ..
# 4606     1
# 23686    1
# 35672    1
# 8550     1
# 34839    1
# Name: ID, Length: 13564, dtype: int64
#
#
# 32    628
# 34    609
# 35    580
# 31    579
# 33    566
#      ...
# 95      1
# 86      1
# 92      1
# 89      1
# 90      1
# Name: age, Length: 75, dtype: int64
#
#
# blue-collar      2890
# management       2819
# technician       2290
# admin.           1540
# services         1251
# retired           690
# entrepreneur      479
# self-employed     456
# unemployed        398
# housemaid         366
# student           303
# unknown            82
# Name: job, dtype: int64
#
#
# married     8119
# single      3868
# divorced    1577
# Name: marital, dtype: int64
#
#
# secondary    6978
# tertiary     4000
# primary      2043
# unknown       543
# Name: education, dtype: int64
#
#
# no     13334
# yes      230
# Name: default, dtype: int64
#
#
#  0       1044
#  1         58
#  2         47
#  3         46
#  4         44
#          ...
# -140        1
#  6495       1
#  8180       1
#  3684       1
#  4256       1
# Name: balance, Length: 4292, dtype: int64
#
#
# yes    7546
# no     6018
# Name: housing, dtype: int64
#
#
# no     11451
# yes     2113
# Name: loan, dtype: int64
#
#
# cellular     8862
# unknown      3843
# telephone     859
# Name: contact, dtype: int64
#
#
# 20    843
# 18    696
# 17    595
# 6     584
# 21    581
# 7     577
# 14    565
# 8     561
# 28    554
# 5     537
# 19    529
# 29    504
# 15    495
# 12    487
# 13    486
# 30    484
# 11    465
# 9     464
# 16    434
# 4     429
# 2     393
# 3     318
# 27    317
# 23    282
# 26    274
# 22    265
# 25    254
# 31    183
# 10    164
# 24    142
# 1     102
# Name: day, dtype: int64
#
#
# may    4097
# jul    2051
# aug    1914
# jun    1603
# nov    1187
# apr     877
# feb     822
# jan     426
# oct     226
# sep     169
# mar     135
# dec      57
# Name: month, dtype: int64
#
#
# 91      63
# 95      62
# 73      61
# 151     60
# 92      59
#         ..
# 572      1
# 799      1
# 1170     1
# 3253     1
# 881      1
# Name: duration, Length: 1201, dtype: int64
#
#
# 1     5282
# 2     3707
# 3     1663
# 4     1080
# 5      519
# 6      375
# 7      217
# 8      184
# 9       91
# 10      82
# 11      75
# 12      53
# 13      40
# 16      25
# 14      25
# 15      23
# 17      17
# 21      16
# 18      14
# 19      14
# 23       9
# 24       7
# 20       6
# 22       5
# 25       5
# 29       4
# 26       4
# 36       3
# 31       3
# 32       3
# 27       2
# 28       2
# 30       2
# 50       1
# 33       1
# 46       1
# 41       1
# 58       1
# 35       1
# 51       1
# Name: campaign, dtype: int64
#
#
# -1      11030
#  182       49
#  92        47
#  181       42
#  183       41
#         ...
#  378        1
#  3          1
#  34         1
#  215        1
#  163        1
# Name: pdays, Length: 422, dtype: int64
#
#
# 0     11030
# 1       851
# 2       625
# 3       362
# 4       213
# 5       148
# 6        89
# 7        67
# 8        48
# 9        28
# 11       19
# 10       18
# 12       14
# 13        8
# 14        5
# 16        5
# 15        5
# 17        4
# 24        3
# 19        3
# 20        3
# 30        2
# 23        2
# 22        2
# 29        2
# 27        1
# 51        1
# 40        1
# 38        1
# 28        1
# 18        1
# 55        1
# 37        1
# Name: previous, dtype: int64
#
#
# unknown    11030
# failure     1539
# other        552
# success      443
# Name: poutcome, dtype: int64

# %%
# dropping id column as it adds no importance to the analysis
df1 = df1.drop('ID', axis=1)
print(df1)
# Out:
#        age          job   marital  education default  balance housing loan  \
# 0       56       admin.   married    unknown      no     1933      no   no
# 1       31      unknown   married  secondary      no        3      no   no
# 2       27     services   married  secondary      no      891     yes   no
# 3       57   management  divorced   tertiary      no     3287      no   no
# 4       31   technician   married  secondary      no      119     yes   no
# ...    ...          ...       ...        ...     ...      ...     ...  ...
# 13559   39   management   married   tertiary      no       45      no   no
# 13560   54  blue-collar   married    primary      no     2281     yes   no
# 13561   35      retired   married    primary      no      285     yes   no
# 13562   29       admin.    single  secondary      no      464      no   no
# 13563   29       admin.   married  secondary      no        2     yes   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome  \
# 0      telephone   19   nov        44         2     -1         0  unknown
# 1       cellular   20   jul        91         2     -1         0  unknown
# 2       cellular   18   jul       240         1     -1         0  unknown
# 3       cellular   22   jun       867         1     84         3  success
# 4       cellular    4   feb       380         1     -1         0  unknown
# ...          ...  ...   ...       ...       ...    ...       ...      ...
# 13559   cellular   28   aug       148         4     -1         0  unknown
# 13560    unknown   20   jun       158         1     -1         0  unknown
# 13561   cellular   29   jan       136         1     -1         0  unknown
# 13562   cellular    9   nov       208         2     91         3  success
# 13563   cellular    6   may       339         1    362         1  failure
#
#       subscribed
# 0             no
# 1             no
# 2             no
# 3            yes
# 4             no
# ...          ...
# 13559        NaN
# 13560        NaN
# 13561        NaN
# 13562        NaN
# 13563        NaN
#
# [45211 rows x 17 columns]

# %%
# dropping id column as it adds no importance to the analysis
df2 = df2.drop('ID', axis=1)
print(df2)
# Out:
#        age            job   marital  education default  balance housing loan  \
# 0       32       services   married  secondary      no      118     yes   no
# 1       78        retired  divorced    primary      no     2787      no   no
# 2       31  self-employed    single   tertiary      no      144     yes   no
# 3       57       services    single    primary      no     3777     yes   no
# 4       45    blue-collar  divorced  secondary      no     -705      no  yes
# ...    ...            ...       ...        ...     ...      ...     ...  ...
# 13559   39     management   married   tertiary      no       45      no   no
# 13560   54    blue-collar   married    primary      no     2281     yes   no
# 13561   35        retired   married    primary      no      285     yes   no
# 13562   29         admin.    single  secondary      no      464      no   no
# 13563   29         admin.   married  secondary      no        2     yes   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome
# 0       cellular   15   may        20         6     -1         0  unknown
# 1      telephone    1   jul       372         1     -1         0  unknown
# 2        unknown   16   may       676         1     -1         0  unknown
# 3      telephone   13   may        65         2     -1         0  unknown
# 4        unknown    3   jul       111         1     -1         0  unknown
# ...          ...  ...   ...       ...       ...    ...       ...      ...
# 13559   cellular   28   aug       148         4     -1         0  unknown
# 13560    unknown   20   jun       158         1     -1         0  unknown
# 13561   cellular   29   jan       136         1     -1         0  unknown
# 13562   cellular    9   nov       208         2     91         3  success
# 13563   cellular    6   may       339         1    362         1  failure
#
# [13564 rows x 16 columns]

# %% [markdown]
# # Data Preprocessing

# %%
#checking for categorical columns
categorical_col=[]
for i in df1.dtypes.index:
    if df1.dtypes[i]=="object":
        categorical_col.append(i)
print("Categorical Columns:",categorical_col)

#checking numerical Columns
numerical_col=[]
for i in df1.dtypes.index:
    if df1.dtypes[i]!="object":
        numerical_col.append(i)
print("Numerical Columns:",numerical_col)
# Out:
# Categorical Columns: ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'poutcome', 'subscribed']
# Numerical Columns: ['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous']

# %%
#checking number of unique values in each column
df1.nunique().to_frame("No.of Unique Values")
# Out:
#             No.of Unique Values
# age                          77
# job                          12
# marital                       3
# education                     4
# default                       2
# balance                    7168
# housing                       2
# loan                          2
# contact                       3
# day                          31
# month                        12
# duration                   1573
# campaign                     48
# pdays                       559
# previous                     41
# poutcome                      4
# subscribed                    2

# %% [markdown]
# # Descriptive Statistics

# %%
df1.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# 75%       -1.000000      0.000000
# max      871.000000    275.000000

# %% [markdown]
# Mean is more 50% in balance, duration,pdays and previous. Hense it highly positve skewed in pdays.there is a huge difference between 75% (Quartile 3) and max in age, balance, duration,campaign,pdays,previous.Hense outliers are present in high numbers in theese columns and we have to treat them.

# %% [markdown]
# # Data Visualization

# %%
# Univarity Analysis
#visualize number of churned ccustomers
ch = sns.countplot(x='subscribed',data=df1)
print (df1['subscribed'].value_counts())
# Out:
# no     27932
# yes     3715
# Name: subscribed, dtype: int64

# %% [markdown]
# Customers who did not subscribe is very high in number when compare to subscribed

# %%
# visulaize the count of Marital
Marriage_Status = sns.countplot(x='marital',data=df1)
print (df1['marital'].value_counts())
# Out:
# married     27214
# single      12790
# divorced     5207
# Name: marital, dtype: int64

# %% [markdown]
# Customers who are approached are majorly marrieed as compared to divorced and single

# %%
# visulaize the count of Marital
Marriage_Status = sns.countplot(x='education',data=df1)
print (df1['education'].value_counts())
# Out:
# secondary    23202
# tertiary     13301
# primary       6851
# unknown       1857
# Name: education, dtype: int64

# %% [markdown]
# Customers having qualification if secondary education have the highest count than other educational qualification

# %%
# visulaize the count of default
Default= sns.countplot(x='default',data=df1)
print (df1['default'].value_counts())
# Out:
# no     44396
# yes      815
# Name: default, dtype: int64

# %% [markdown]
# Majority of the customers were not default, Customers defaulting are very less in number.

# %%
# visulaize the count of housing
Default= sns.countplot(x='housing',data=df1)
print (df1['housing'].value_counts())
# Out:
# yes    25130
# no     20081
# Name: housing, dtype: int64

# %% [markdown]
# People having Loans are more in number than People having no loans.

# %%
# visulaize the count of loan
Default= sns.countplot(x='loan',data=df1)
print (df1['loan'].value_counts())
# Out:
# no     37967
# yes     7244
# Name: loan, dtype: int64

# %% [markdown]
# Majority of the people do not have personal loans.  Very few people have personal loan on them.

# %%
# visulaize the count of default
Default= sns.countplot(x='contact',data=df1)
print (df1['contact'].value_counts())
# Out:
# cellular     29285
# unknown      13020
# telephone     2906
# Name: contact, dtype: int64

# %% [markdown]
# Majority of the Customers contacted have cellular phones.

# %%
# visulaize the count of default
Default= sns.countplot(x='poutcome',data=df1)
print (df1['poutcome'].value_counts())
# Out:
# unknown    36959
# failure     4901
# other       1840
# success     1511
# Name: poutcome, dtype: int64

# %% [markdown]
# Outcome of previous marketing campaign is unknown in majority of the cases.

# %%
#Letss check how data is disctributed in numerical columns
plt.figure(figsize = (10,6), facecolor="white")
plotnumber= 1
for col in numerical_col:
    if plotnumber<=7:
        ax = plt.subplot (3,3,plotnumber)
        sns.distplot (df1[col],color='m')
        plt.xlabel(col,fontsize= 12 )
        plt.yticks(rotation=0,fontsize=10)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# Balance, duration,campaign,pdays, previous are all right skewed data.

# %%
#Bivariate Analysis
#checking subscribed and marital
sns.catplot (x="subscribed", col="marital",data=df1, kind="count",palette='spring_r')

#checking subscribed and poutcome
sns.catplot (x="subscribed", col="poutcome",data=df1, kind="count",palette='tab20b_r')

#checking subscribed in default
sns.catplot (x="subscribed", col="default",data=df1, kind="count",palette='twilight_shifted')

#checking subscribed in housing
sns.catplot (x="subscribed", col="housing",data=df1, kind="count",palette='Dark2')

#checking subscribed in loan
sns.catplot (x="subscribed", col="loan",data=df1, kind="count",palette='Dark2')
plt.show()

# %% [markdown]
# It is observed that customers who were married did not subscribe for loans,Customers who subscribed or did not subscribe to the loans ,their otucomen for previous is campaign is unknown.Customers who had housing loans did not subscribe for loans. Even though majority of the customers did not have personal loans yet they did not subscribe for Deposits.

# %%
plt.title("Comparison of day and duration")
sns.scatterplot (x="day", y="duration",data=df1, hue='subscribed',palette='bright')
plt.show()

# %%
plt.title("Comparison of day and balance")
sns.scatterplot (x="day", y="balance",data=df1, hue='subscribed',palette='bright')
plt.show()

# %% [markdown]
# # Multivariatee Analysis

# %%
sns.pairplot(df1,hue="subscribed", palette="Dark2")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Outliers

# %% [markdown]
# huge number of Outliers are present in balance,duration,campaign,pdays and previous. and some counts in age.

# %% [markdown]
# # Replacing categorical data to numerical data

# %%
#changing the categorical data into numerical data 
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
for column in df1.columns:
    if df1[column].dtype == 'object':
        df1[column] = label_encoder.fit_transform(df1[column])

print(df1.head())
# Out:
#    age  job  marital  education  default  balance  housing  loan  contact  \
# 0   56    0        1          3        0     1933        0     0        1
# 1   31   11        1          1        0        3        0     0        0
# 2   27    7        1          1        0      891        1     0        0
# 3   57    4        0          2        0     3287        0     0        0
# 4   31    9        1          1        0      119        1     0        0
#
#    day  month  duration  campaign  pdays  previous  poutcome  subscribed
# 0   19      9        44         2     -1         0         3           0
# 1   20      5        91         2     -1         0         3           0
# 2   18      5       240         1     -1         0         3           0
# 3   22      6       867         1     84         3         2           1
# 4    4      3       380         1     -1         0         3           0

# %%
#changing the categorical data into numerical data 
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
for column in df2.columns:
    if df2[column].dtype == 'object':
        df2[column] = label_encoder.fit_transform(df2[column])

print(df2.head())
# Out:
#    age  job  marital  education  default  balance  housing  loan  contact  \
# 0   32    7        1          1        0      118        1     0        0
# 1   78    5        0          0        0     2787        0     0        1
# 2   31    6        2          2        0      144        1     0        2
# 3   57    7        2          0        0     3777        1     0        1
# 4   45    1        0          1        0     -705        0     1        2
#
#    day  month  duration  campaign  pdays  previous  poutcome
# 0   15      8        20         6     -1         0         3
# 1    1      5       372         1     -1         0         3
# 2   16      8       676         1     -1         0         3
# 3   13      8        65         2     -1         0         3
# 4    3      5       111         1     -1         0         3

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45211 entries, 0 to 13563
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   age         45211 non-null  int64
#  1   job         45211 non-null  int32
#  2   marital     45211 non-null  int32
#  3   education   45211 non-null  int32
#  4   default     45211 non-null  int32
#  5   balance     45211 non-null  int64
#  6   housing     45211 non-null  int32
#  7   loan        45211 non-null  int32
#  8   contact     45211 non-null  int32
#  9   day         45211 non-null  int64
#  10  month       45211 non-null  int32
#  11  duration    45211 non-null  int64
#  12  campaign    45211 non-null  int64
#  13  pdays       45211 non-null  int64
#  14  previous    45211 non-null  int64
#  15  poutcome    45211 non-null  int32
#  16  subscribed  45211 non-null  int32
# dtypes: int32(10), int64(7)
# memory usage: 4.5 MB

# %% [markdown]
# # Correlation between Target variables and independent variables

# %%
cor=df1.corr()
cor
# Out:
#                  age       job   marital  education   default   balance  \
# age         1.000000 -0.021868 -0.403240  -0.106807 -0.017879  0.097783
# job        -0.021868  1.000000  0.062045   0.166707 -0.006853  0.018232
# marital    -0.403240  0.062045  1.000000   0.108576 -0.007023  0.002122
# education  -0.106807  0.166707  0.108576   1.000000 -0.010718  0.064514
# default    -0.017879 -0.006853 -0.007023  -0.010718  1.000000 -0.066745
# balance     0.097783  0.018232  0.002122   0.064514 -0.066745  1.000000
# housing    -0.185513 -0.125363 -0.016096  -0.090790 -0.006025 -0.068768
# loan       -0.015655 -0.033004 -0.046893  -0.048574  0.077234 -0.084350
# contact     0.026221 -0.082063 -0.039201  -0.110928  0.015404 -0.027273
# day        -0.009120  0.022856 -0.005261   0.022671  0.009424  0.004503
# month      -0.042357 -0.092870 -0.006991  -0.057304  0.011486  0.019777
# duration   -0.004648  0.004744  0.011852   0.001935 -0.010021  0.021560
# campaign    0.004760  0.006839 -0.008994   0.006255  0.016822 -0.014578
# pdays      -0.023758 -0.024455  0.019172   0.000052 -0.029979  0.003435
# previous    0.001288 -0.000911  0.014973   0.017570 -0.018329  0.016674
# poutcome    0.007367  0.011010 -0.016850  -0.019361  0.034898 -0.020967
# subscribed  0.003232  0.012748  0.012669   0.016101 -0.010116  0.011823
#
#              housing      loan   contact       day     month  duration  \
# age        -0.185513 -0.015655  0.026221 -0.009120 -0.042357 -0.004648
# job        -0.125363 -0.033004 -0.082063  0.022856 -0.092870  0.004744
# marital    -0.016096 -0.046893 -0.039201 -0.005261 -0.006991  0.011852
# education  -0.090790 -0.048574 -0.110928  0.022671 -0.057304  0.001935
# default    -0.006025  0.077234  0.015404  0.009424  0.011486 -0.010021
# balance    -0.068768 -0.084350 -0.027273  0.004503  0.019777  0.021560
# housing     1.000000  0.041323  0.188123 -0.027982  0.271481  0.005075
# loan        0.041323  1.000000 -0.010873  0.011370  0.022145 -0.012412
# contact     0.188123 -0.010873  1.000000 -0.027936  0.361145 -0.020839
# day        -0.027982  0.011370 -0.027936  1.000000 -0.006028 -0.030206
# month       0.271481  0.022145  0.361145 -0.006028  1.000000  0.006314
# duration    0.005075 -0.012412 -0.020839 -0.030206  0.006314  1.000000
# campaign   -0.023599  0.009980  0.019614  0.162490 -0.110031 -0.084570
# pdays       0.124178 -0.022754 -0.244816 -0.093044  0.033065 -0.001565
# previous    0.037076 -0.011043 -0.147811 -0.051710  0.022727  0.001203
# poutcome   -0.099971  0.015458  0.272214  0.083460 -0.033038  0.010925
# subscribed -0.034563 -0.025677 -0.044616 -0.012481 -0.011902  0.097312
#
#             campaign     pdays  previous  poutcome  subscribed
# age         0.004760 -0.023758  0.001288  0.007367    0.003232
# job         0.006839 -0.024455 -0.000911  0.011010    0.012748
# marital    -0.008994  0.019172  0.014973 -0.016850    0.012669
# education   0.006255  0.000052  0.017570 -0.019361    0.016101
# default     0.016822 -0.029979 -0.018329  0.034898   -0.010116
# balance    -0.014578  0.003435  0.016674 -0.020967    0.011823
# housing    -0.023599  0.124178  0.037076 -0.099971   -0.034563
# loan        0.009980 -0.022754 -0.011043  0.015458   -0.025677
# contact     0.019614 -0.244816 -0.147811  0.272214   -0.044616
# day         0.162490 -0.093044 -0.051710  0.083460   -0.012481
# month      -0.110031  0.033065  0.022727 -0.033038   -0.011902
# duration   -0.084570 -0.001565  0.001203  0.010925    0.097312
# campaign    1.000000 -0.088628 -0.032855  0.101588   -0.018565
# pdays      -0.088628  1.000000  0.454820 -0.858362    0.035832
# previous   -0.032855  0.454820  1.000000 -0.489752    0.026924
# poutcome    0.101588 -0.858362 -0.489752  1.000000   -0.029131
# subscribed -0.018565  0.035832  0.026924 -0.029131    1.000000

# %%
#visualizing corr by ploting heatmap
plt.figure(figsize=(20,15))
sns.heatmap (df1.corr(), linewidths=0.1,fmt=".1g",linecolor="black", annot=True,cmap="Blues_r")
plt.yticks(rotation=0)
plt.show()

# %% [markdown]
# pdays and poutcomes are highly correlated to each other. Lets find the correlation of target variable with features.

# %%
cor["subscribed"].sort_values(ascending=True)
# Out:
# contact      -0.044616
# housing      -0.034563
# poutcome     -0.029131
# loan         -0.025677
# campaign     -0.018565
# day          -0.012481
# month        -0.011902
# default      -0.010116
# age           0.003232
# balance       0.011823
# marital       0.012669
# job           0.012748
# education     0.016101
# previous      0.026924
# pdays         0.035832
# duration      0.097312
# subscribed    1.000000
# Name: subscribed, dtype: float64

# %%
plt.figure(figsize=(22,7))
df1.corr()["subscribed"].sort_values(ascending=False).drop(["subscribed"]).plot(kind='bar',color="m")
plt.xlabel("feature",fontsize=15)
plt.ylabel("subscribed",fontsize=15)
plt.title("Correlation between label andd features using Barplot", fontsize=20)
plt.show()

# %% [markdown]
# Only duration has moderate correlation with subscribed. Apart from that there is no noticeable correlation between target and features.

# %% [markdown]
# # Separating Features and Label(target)

# %%
train_df=df1[df1['subscribed'] !=2.0]
train_df
# Out:
#        age  job  marital  education  default  balance  housing  loan  contact  \
# 0       56    0        1          3        0     1933        0     0        1
# 1       31   11        1          1        0        3        0     0        0
# 2       27    7        1          1        0      891        1     0        0
# 3       57    4        0          2        0     3287        0     0        0
# 4       31    9        1          1        0      119        1     0        0
# ...    ...  ...      ...        ...      ...      ...      ...   ...      ...
# 31642   29    4        2          2        0        0        1     0        0
# 31643   53    4        0          2        0      380        0     1        0
# 31644   32    4        2          2        0      312        0     0        0
# 31645   57    9        1          1        0      225        1     0        1
# 31646   55    4        0          1        0      204        1     0        0
#
#        day  month  duration  campaign  pdays  previous  poutcome  subscribed
# 0       19      9        44         2     -1         0         3         0.0
# 1       20      5        91         2     -1         0         3         0.0
# 2       18      5       240         1     -1         0         3         0.0
# 3       22      6       867         1     84         3         2         1.0
# 4        4      3       380         1     -1         0         3         0.0
# ...    ...    ...       ...       ...    ...       ...       ...         ...
# 31642   12      8       116         2     -1         0         3         0.0
# 31643    5      6       438         2     -1         0         3         1.0
# 31644    7      1        37         3     -1         0         3         0.0
# 31645   15      8        22         7    337        12         0         0.0
# 31646   11      5      1973         2     -1         0         3         1.0
#
# [31647 rows x 17 columns]

# %%
test_df=df1[df1['subscribed']==2.0]
test_df.drop('subscribed',axis=1,inplace=True)

# %%
train_df.shape,test_df.shape
# Out:
# ((31647, 17), (13564, 16))

# %%
x=train_df.drop("subscribed",axis=1)
y=train_df["subscribed"].values

# %% [markdown]
# # Feature Scaling using Standard Scalarization

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=pd.DataFrame(sc.fit_transform(x),columns=x.columns)
x
# Out:
#             age       job   marital  education   default   balance   housing  \
# 0      1.415793 -1.324317 -0.275405   2.369229 -0.137234  0.187933 -1.118201
# 1     -0.937156  2.037729 -0.275405  -0.300345 -0.137234 -0.449397 -1.118201
# 2     -1.313627  0.815167 -0.275405  -0.300345 -0.137234 -0.156159  0.894294
# 3      1.509911 -0.101755 -1.922374   1.034442 -0.137234  0.635055 -1.118201
# 4     -0.937156  1.426448 -0.275405  -0.300345 -0.137234 -0.411091  0.894294
# ...         ...       ...       ...        ...       ...       ...       ...
# 31642 -1.125392 -0.101755  1.371563   1.034442 -0.137234 -0.450388  0.894294
# 31643  1.133439 -0.101755 -1.922374   1.034442 -0.137234 -0.324903 -1.118201
# 31644 -0.843038 -0.101755  1.371563   1.034442 -0.137234 -0.347358 -1.118201
# 31645  1.509911  1.426448 -0.275405  -0.300345 -0.137234 -0.376088  0.894294
# 31646  1.321675 -0.101755 -1.922374  -0.300345 -0.137234 -0.383022  0.894294
#
#            loan   contact       day     month  duration  campaign     pdays  \
# 0     -0.439893  0.395076  0.379579  1.154007 -0.832754 -0.245906 -0.408555
# 1     -0.439893 -0.716695  0.499526 -0.177462 -0.649957 -0.245906 -0.408555
# 2     -0.439893 -0.716695  0.259631 -0.177462 -0.070449 -0.567059 -0.408555
# 3     -0.439893 -0.716695  0.739422  0.155405  2.368149 -0.567059  0.447299
# 4     -0.439893 -0.716695 -1.419637 -0.843197  0.474054 -0.567059 -0.408555
# ...         ...       ...       ...       ...       ...       ...       ...
# 31642 -0.439893 -0.716695 -0.460055  0.821140 -0.552724 -0.245906 -0.408555
# 31643  2.273280 -0.716695 -1.299690  0.155405  0.699635 -0.245906 -0.408555
# 31644 -0.439893 -0.716695 -1.059794 -1.508931 -0.859979  0.075247 -0.408555
# 31645 -0.439893  0.395076 -0.100212  0.821140 -0.918319  1.359859  2.994723
# 31646 -0.439893 -0.716695 -0.580003 -0.177462  6.669728 -0.245906 -0.408555
#
#        previous  poutcome
# 0     -0.237059  0.441777
# 1     -0.237059  0.441777
# 2     -0.237059  0.441777
# 3      1.001336 -0.576498
# 4     -0.237059  0.441777
# ...         ...       ...
# 31642 -0.237059  0.441777
# 31643 -0.237059  0.441777
# 31644 -0.237059  0.441777
# 31645  4.716521 -2.613048
# 31646 -0.237059  0.441777
#
# [31647 rows x 16 columns]

# %% [markdown]
# # Checking Variace inflation factor(VIF)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
v=variance_inflation_factor
vif=pd.DataFrame()
vif["VIF Values"]=[v(x.values,i) for i in range(len(x.columns))]
vif["Features"]=x.columns
vif
# Out:
#     VIF Values   Features
# 0     1.283253        age
# 1     1.050495        job
# 2     1.222506    marital
# 3     1.067258  education
# 4     1.012817    default
# 5     1.034343    balance
# 6     1.191470    housing
# 7     1.020545       loan
# 8     1.321742    contact
# 9     1.037956        day
# 10    1.249806      month
# 11    1.008945   duration
# 12    1.055276   campaign
# 13    3.850393      pdays
# 14    1.281110   previous
# 15    4.042436   poutcome

# %% [markdown]
# As all the vif values are less than 5. There is no multicollinearity in any of the columns

# %%
y
# Out:
# array([0., 0., 0., ..., 0., 0., 1.])

# %% [markdown]
# The data is imbalanced , so we havee to Balance the target variable

# %%
# !pip install scikit-learn==1.2.2
# !pip install imblearn
# Out:
# Requirement already satisfied: scikit-learn==1.2.2 in c:\users\vkvar\anaconda3\lib\site-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\vkvar\anaconda3\lib\site-packages (from scikit-learn==1.2.2) (1.24.3)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\vkvar\anaconda3\lib\site-packages (from scikit-learn==1.2.2) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\vkvar\anaconda3\lib\site-packages (from scikit-learn==1.2.2) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\vkvar\anaconda3\lib\site-packages (from scikit-learn==1.2.2) (2.2.0)
# Requirement already satisfied: imblearn in c:\users\vkvar\anaconda3\lib\site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in c:\users\vkvar\anaconda3\lib\site-packages (from imblearn) (0.10.1)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\vkvar\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.24.3)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\vkvar\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.10.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\vkvar\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\vkvar\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\vkvar\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (2.2.0)

# %%
from imblearn.over_sampling import SMOTE

# %%
SM=SMOTE()
x1, y1 = SM.fit_resample(x,y)

# %%
x1.value_counts()
# Out:
# age        job        marital    education  default    balance    housing    loan       contact    day        month      duration   campaign   pdays      previous   poutcome
# -2.160689   1.120808   1.371563  -1.635132  -0.137234  -0.249612  -1.118201  -0.439893  -0.716695  -0.460055  -1.508931   0.034562  -0.567059  -0.408555  -0.237059  0.441777    1
#  0.380496  -0.713036  -0.275405   1.034442  -0.137234  -0.450388   0.894294  -0.439893   1.506847   0.499526   0.155405  -0.809418  -0.245906  -0.408555  -0.237059  0.441777    1
#                                  -0.300345  -0.137234  -0.608565   0.894294  -0.439893  -0.716695   1.699004  -0.177462  -0.354369  -0.245906  -0.408555  -0.237059  0.441777    1
#                                                        -0.427933   0.894294  -0.439893   1.506847  -1.059794   0.821140  -0.015999  -0.567059  -0.408555  -0.237059  0.441777    1
#                                                        -0.415054  -1.118201  -0.439893  -0.716695   0.379579  -1.508931  -0.502163   2.644471  -0.408555  -0.237059  0.441777    1
#                                                                                                                                                                                 ..
# -0.654802   0.203886  -0.275405  -1.635132  -0.137234   1.035285  -1.118201  -0.439893   1.506847   0.619474   0.821140   5.534049  -0.567059  -0.408555  -0.237059  0.441777    1
#             0.261076   1.371563   1.034442  -0.137234   3.248923  -1.118201  -0.439893  -0.716695   0.158264  -1.508931   1.256976  -0.567059  -0.408555  -0.237059  0.441777    1
#             0.309517   1.371563   1.034442  -0.137234   3.169057  -1.118201  -0.439893  -0.716695   0.224800  -1.508931   1.175609  -0.567059  -0.408555  -0.237059  0.441777    1
#             0.465476   1.371563   1.034442  -0.137234   2.911921  -1.118201  -0.439893  -0.716695   0.439020  -1.508931   0.913642  -0.567059  -0.408555  -0.237059  0.441777    1
#  5.086393   0.203886  -1.922374  -1.635132  -0.137234   0.303181  -1.118201  -0.439893   0.395076   0.619474  -1.841799  -0.198796   4.571389  -0.408555  -0.237059  0.441777    1
# Length: 55864, dtype: int64

# %%
print("Shape of x1:", x1.shape)
print("Shape of y1:", y1.shape)
# Out:
# Shape of x1: (55864, 16)
# Shape of y1: (55864,)

# %% [markdown]
# # Modelling or Model Building

# %%
from sklearn.model_selection import train_test_split
x_train, x_cv, y_train, y_cv = train_test_split(x1, y1, test_size=0.2, random_state=42)

# %%
print('Size of x_train : ', x_train.shape)
print('Size of y_train : ', y_train.shape)
print('Size of x_cv : ', x_cv.shape)
print('Size of y_cv : ', y_cv.shape)
# Out:
# Size of x_train :  (44691, 16)
# Size of y_train :  (44691,)
# Size of x_cv :  (11173, 16)
# Size of y_cv :  (11173,)

# %% [markdown]
# # Classification Algorithm and Cross-Valuation Score

# %%
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier,GradientBoostingClassifier,AdaBoostClassifier,BaggingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, accuracy_score
from sklearn.model_selection import cross_val_score

# %%
# checking accuracy for RandomForestClassifier
RFC=RandomForestClassifier()
RFC.fit(x_train,y_train)
predRFC=RFC.predict(x_cv)
print(accuracy_score(y_cv,predRFC))
print(confusion_matrix(y_cv,predRFC))
print(classification_report(y_cv,predRFC))
#checking cv score for Random Forest classifier
score1=cross_val_score(RFC,x1,y1)
print(score1)
print(score1.mean())
print("Difference between Accuraccy_Score and CVS is =", accuracy_score(y_cv,predRFC)-score1.mean())
# Out:
# 0.9493421641457084
# [[5226  377]
#  [ 189 5381]]
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.93      0.95      5603
#          1.0       0.93      0.97      0.95      5570
#
#     accuracy                           0.95     11173
#    macro avg       0.95      0.95      0.95     11173
# weighted avg       0.95      0.95      0.95     11173
#
# [0.8909872  0.95829231 0.95703929 0.95954533 0.95488722]
# 0.9441502709606739
# Difference between Accuraccy_Score and CVS is = 0.005191893185034435

# %%
#Lets plot confusion mTatrix for RandomForestClassifier
cm=confusion_matrix(y_cv,predRFC)
x_axis_labels=["0","1"]
y_axis_labels= ["0","1"]
f, ax = plt.subplots(figsize=(7,7))
sns.heatmap(cm,annot=True, linewidths=0.2, linecolor="black",fmt=".0f",ax=ax, xticklabels=x_axis_labels, yticklabels=y_axis_labels)
plt.xlabel("Predicted label")
plt.ylabel("True Label")
plt.title("Confusion Matrix for randomForestClassifier")
plt.show()

# %%
svc=SVC()
svc.fit(x_train,y_train)
predsvc=svc.predict(x_cv)
print(accuracy_score(y_cv,predsvc))
print(confusion_matrix(y_cv,predsvc))
print(classification_report(y_cv,predsvc))
#checking cv score for Support Vector classifier
score2=cross_val_score(svc,x1,y1)
print(score2)
print(score2.mean())
print("Difference between Accuraccy_Score and CVS is =", accuracy_score(y_cv,predsvc)-score2.mean())
# Out:
# 0.8642262597332856
# [[4609  994]
#  [ 523 5047]]
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.82      0.86      5603
#          1.0       0.84      0.91      0.87      5570
#
#     accuracy                           0.86     11173
#    macro avg       0.87      0.86      0.86     11173
# weighted avg       0.87      0.86      0.86     11173
#
# [0.85769265 0.86422626 0.86744831 0.86914884 0.86672037]
# 0.8650472875749102
# Difference between Accuraccy_Score and CVS is = -0.000821027841624633

# %%
GB=GradientBoostingClassifier()
GB.fit(x_train,y_train)
predGB=GB.predict(x_cv)
print(accuracy_score(y_cv,predGB))
print(confusion_matrix(y_cv,predGB))
print(classification_report(y_cv,predGB))
#checking cv score for Gradient Boosting classifier
score3=cross_val_score(GB,x1,y1)
print(score3)
print(score3.mean())
print("Difference between Accuraccy_Score and CVS is =", accuracy_score(y_cv,predGB)-score3.mean())
# Out:
# 0.9178376443211314
# [[5069  534]
#  [ 384 5186]]
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.90      0.92      5603
#          1.0       0.91      0.93      0.92      5570
#
#     accuracy                           0.92     11173
#    macro avg       0.92      0.92      0.92     11173
# weighted avg       0.92      0.92      0.92     11173
#
# [0.82314508 0.92795131 0.92660879 0.93233688 0.92776584]
# 0.9075615817746921
# Difference between Accuraccy_Score and CVS is = 0.010276062546439202

# %%
ABC=AdaBoostClassifier()
ABC.fit(x_train,y_train)
predABC=ABC.predict(x_cv)
print(accuracy_score(y_cv,predABC))
print(confusion_matrix(y_cv,predABC))
print(classification_report(y_cv,predABC))
#checking cv score for AdaBoosting classifier
score4=cross_val_score(ABC,x1,y1)
print(score4)
print(score4.mean())
print("Difference between Accuraccy_Score and CVS is =", accuracy_score(y_cv,predABC)-score4.mean())
# Out:
# 0.8852591067752618
# [[4960  643]
#  [ 639 4931]]
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.89      0.89      5603
#          1.0       0.88      0.89      0.88      5570
#
#     accuracy                           0.89     11173
#    macro avg       0.89      0.89      0.89     11173
# weighted avg       0.89      0.89      0.89     11173
#
# [0.81356842 0.89931084 0.89322474 0.89993735 0.90037594]
# 0.8812834579063787
# Difference between Accuraccy_Score and CVS is = 0.003975648868883019

# %%
LR=LogisticRegression()
LR.fit(x_train,y_train)
predLR=LR.predict(x_cv)
print(accuracy_score(y_cv,predLR))
print(confusion_matrix(y_cv,predLR))
print(classification_report(y_cv,predLR))
#checking cv score for Logistic regresssion
score5=cross_val_score(LR,x1,y1)
print(score5)
print(score5.mean())
print("Difference between Accuraccy_Score and CVS is =", accuracy_score(y_cv,predLR)-score5.mean())
# Out:
# 0.8073033205047884
# [[4520 1083]
#  [1070 4500]]
#               precision    recall  f1-score   support
#
#          0.0       0.81      0.81      0.81      5603
#          1.0       0.81      0.81      0.81      5570
#
#     accuracy                           0.81     11173
#    macro avg       0.81      0.81      0.81     11173
# weighted avg       0.81      0.81      0.81     11173
#
# [0.80434977 0.80837734 0.81016737 0.81777499 0.81015038]
# 0.8101639693972243
# Difference between Accuraccy_Score and CVS is = -0.0028606488924359796

# %%
BC=BaggingClassifier()
BC.fit(x_train,y_train)
predBC=BC.predict(x_cv)
print(accuracy_score(y_cv,predBC))
print(confusion_matrix(y_cv,predBC))
print(classification_report(y_cv,predBC))
#checking cv score for Bagging classifier
score6=cross_val_score(BC,x1,y1)
print(score6)
print(score6.mean())
print("Difference between Accuraccy_Score and CVS is =", accuracy_score(y_cv,predBC)-score6.mean())
# Out:
# 0.9357379396760046
# [[5234  369]
#  [ 349 5221]]
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.93      0.94      5603
#          1.0       0.93      0.94      0.94      5570
#
#     accuracy                           0.94     11173
#    macro avg       0.94      0.94      0.94     11173
# weighted avg       0.94      0.94      0.94     11173
#
# [0.85160655 0.94808914 0.94978967 0.94764164 0.94951665]
# 0.9293287302720625
# Difference between Accuraccy_Score and CVS is = 0.006409209403942073

# %%
ET=ExtraTreesClassifier()
ET.fit(x_train,y_train)
predET=ET.predict(x_cv)
print(accuracy_score(y_cv,predET))
print(confusion_matrix(y_cv,predET))
print(classification_report(y_cv,predET))
#checking cv score for Extra Tree classifier
score7=cross_val_score(ET,x1,y1)
print(score7)
print(score7.mean())
print("Difference between Accuraccy_Score and CVS is =", accuracy_score(y_cv,predET)-score7.mean())
# Out:
# 0.9630358900921865
# [[5262  341]
#  [  72 5498]]
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.94      0.96      5603
#          1.0       0.94      0.99      0.96      5570
#
#     accuracy                           0.96     11173
#    macro avg       0.96      0.96      0.96     11173
# weighted avg       0.96      0.96      0.96     11173
#
# [0.95104269 0.96751096 0.96715296 0.96518393 0.96437522]
# 0.9630531526935251
# Difference between Accuraccy_Score and CVS is = -1.7262601338607908e-05

# %%
model=[('RandomForestClassifier',accuracy_score(y_cv,predRFC),score1.mean(),accuracy_score(y_cv,predRFC)-score1.mean()),
      ('SVC',accuracy_score(y_cv,predsvc),score2.mean(),accuracy_score(y_cv,predsvc)-score2.mean()),
      ('GradientBoostingClassifier',accuracy_score(y_cv,predGB),score3.mean(),accuracy_score(y_cv,predGB)-score3.mean()),
      ('AdaBoostClassifier',accuracy_score(y_cv,predABC),score4.mean(),accuracy_score(y_cv,predABC)-score4.mean()),
      ('LogisticRegression',accuracy_score(y_cv,predLR),score5.mean(),accuracy_score(y_cv,predLR)-score5.mean()),
      ('BaggingClassifier',accuracy_score(y_cv,predBC),score6.mean(),accuracy_score(y_cv,predBC)-score6.mean()),
      ('ExtraTreesClassifier',accuracy_score(y_cv,predET),score7.mean(),accuracy_score(y_cv,predET)-score7.mean()),
      ]

# %%
Model = pd.DataFrame(data = model, columns=['Model','Accuracy Score','Cross Validation', 'Difference'])
Model
# Out:
#                         Model  Accuracy Score  Cross Validation  Difference
# 0      RandomForestClassifier        0.949342          0.944150    0.005192
# 1                         SVC        0.864226          0.865047   -0.000821
# 2  GradientBoostingClassifier        0.917838          0.907562    0.010276
# 3          AdaBoostClassifier        0.885259          0.881283    0.003976
# 4          LogisticRegression        0.807303          0.810164   -0.002861
# 5           BaggingClassifier        0.935738          0.929329    0.006409
# 6        ExtraTreesClassifier        0.963036          0.963053   -0.000017

# %% [markdown]
# Since Extra Tree Classifier is the best model use Hypertuning with ETC

# %%
# Extra Trees classifier 
from sklearn.model_selection import GridSearchCV
parameters={'criterion': ['gini','entropy'],
           'random_state':[10,50,1000],
           'max_depth':[0,10,20],
            'n_jobs':[-2,-1,1],
           'n_estimators':[50,100,200,300]}

# %%
GCV=GridSearchCV(ExtraTreesClassifier(),parameters,cv=5)

# %%
Final_model=ExtraTreesClassifier(criterion='gini',max_depth=20,n_estimators=300,n_jobs=-1, random_state=10)
Final_model.fit(x_train,y_train)
prediction=Final_model.predict(df2)
prediction
# Out:
# array([1., 1., 1., ..., 1., 1., 1.])

# %% [markdown]
# # Plotting ROC AUC Curve

# %%
#Plotting for all the models used here
from sklearn import datasets
from sklearn import metrics
from sklearn import model_selection
from sklearn.metrics import RocCurveDisplay

# %%
display= RocCurveDisplay.from_estimator(RFC,x_cv,y_cv) #ax =Axes with confusion Matrix
RocCurveDisplay.from_estimator(ET,x_cv,y_cv)
RocCurveDisplay.from_estimator(LR,x_cv,y_cv)
RocCurveDisplay.from_estimator(svc,x_cv,y_cv)
RocCurveDisplay.from_estimator(GB,x_cv,y_cv)
RocCurveDisplay.from_estimator(ABC,x_cv,y_cv)
RocCurveDisplay.from_estimator(BC,x_cv,y_cv)

plt.legend(prop={'size':11},loc='lower right')
plt.show()

# %% [markdown]
# # Plotting ROC and compare AUC for thr Best Model

# %%
#Lets check the AUC for the best model after hyper parameter tuning
RocCurveDisplay.from_estimator(Final_model,df2,pred)
plt.title("ROC for the Best Model")
plt.show()

# %%
from sklearn import metrics
fpr,tpr,thesholds=metrics.roc_curve(prediction,pred)
roc_auc=metrics.auc(fpr,tpr)
display=metrics.RocCurveDisplay(fpr=fpr,tpr=tpr,roc_auc=roc_auc,estimator_name=Final_model)
display.plot()

# %% [markdown]
# here we have plotted the ROC curve for the final model and the AUC value for the best model is 93%

# %% [markdown]
# # Saving the Final Model

# %%
#saving the model using .pkl
import joblib
joblib.dump(Final_model,"Bank_Marketing_Prediction.pkl")
# Out:
# ['Bank_Marketing_Prediction.pkl']

# %% [markdown]
# # Make Predictions on Test Data:

# %%
#lets load the saved model and get the predictions
model=joblib.load('Bank_Marketing_Prediction.pkl')

# %%
#Prediction
x_test=df2
prediction=model.predict(x_test)
prediction
# Out:
# array([1., 1., 1., ..., 1., 1., 1.])
