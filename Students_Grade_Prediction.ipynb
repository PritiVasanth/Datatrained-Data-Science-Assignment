# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("https://raw.githubusercontent.com/FlipRoboTechnologies/ML-Datasets/main/Grades/Grades.csv")
df
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 0    CS-97001     B-     D+     C-         C     C-     D+      D     C-
# 1    CS-97002      A      D     D+         D     B-      C      D      A
# 2    CS-97003      A      B      A        B-     B+      A     B-     B+
# 3    CS-97004      D     C+     D+         D      D     A-     D+     C-
# 4    CS-97005     A-     A-     A-        B+      A      A     A-     B+
# ..        ...    ...    ...    ...       ...    ...    ...    ...    ...
# 566  CS-97567      B      A      A        A-     A+      A     A-     A-
# 567  CS-97568     A+      A      A         A      A      A      A     A-
# 568  CS-97569      B      A     A-        B+      A      A      A      A
# 569  CS-97570      A     B+      D         A      D     D+     B-     C-
# 570  CS-97571      C      D      D         C      C     D+      B     C+
#
#     EE-119  ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423  \
# ...

# %%
df.head()
# Out:
#    Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119  \
# 0  CS-97001     B-     D+     C-         C     C-     D+      D     C-     B-
# 1  CS-97002      A      D     D+         D     B-      C      D      A     D+
# 2  CS-97003      A      B      A        B-     B+      A     B-     B+     A-
# 3  CS-97004      D     C+     D+         D      D     A-     D+     C-      D
# 4  CS-97005     A-     A-     A-        B+      A      A     A-     B+      A
#
#    ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423 CS-412   CGPA
# 0  ...     C-     C-     C-     C-     A-      A     C-      B     A-  2.205
# 1  ...     D+      D      C      D     A-     B-      C      C      B  2.008
# 2  ...      B      B      A      C      A      A      A     A-      A  3.608
# 3  ...     D+      C     D+     C-     B-      B     C+     C+     C+  1.906
# 4  ...     B-     B+     B+     B-     A-      A     A-     A-      A  3.448
#
# [5 rows x 43 columns]

# %%
df.tail()
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 566  CS-97567      B      A      A        A-     A+      A     A-     A-
# 567  CS-97568     A+      A      A         A      A      A      A     A-
# 568  CS-97569      B      A     A-        B+      A      A      A      A
# 569  CS-97570      A     B+      D         A      D     D+     B-     C-
# 570  CS-97571      C      D      D         C      C     D+      B     C+
#
#     EE-119  ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423  \
# 566     A+  ...     A-     A-      A      A      A     B+     B+      B
# 567      A  ...     B+     B+      A      A     A-      B     A-      C
# 568      A  ...     A-      B      A     B+      A      C     B+     A-
# 569     B-  ...      D      B      B     C-      D      C      B     B-
# 570      C  ...     C+      C     B-      D      F     C-     B+      D
#
#     CS-412   CGPA
# 566      A  3.798
# 567     A-  3.772
# 568     A-  3.470
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 43 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Seat No.   571 non-null    object
#  1   PH-121     571 non-null    object
#  2   HS-101     571 non-null    object
#  3   CY-105     570 non-null    object
#  4   HS-105/12  570 non-null    object
#  5   MT-111     569 non-null    object
#  6   CS-105     571 non-null    object
#  7   CS-106     569 non-null    object
#  8   EL-102     569 non-null    object
#  9   EE-119     569 non-null    object
#  10  ME-107     569 non-null    object
#  11  CS-107     569 non-null    object
#  12  HS-205/20  566 non-null    object
#  13  MT-222     566 non-null    object
#  14  EE-222     564 non-null    object
#  15  MT-224     564 non-null    object
#  16  CS-210     564 non-null    object
#  17  CS-211     566 non-null    object
#  18  CS-203     566 non-null    object
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 0    CS-97001     B-     D+     C-         C     C-     D+      D     C-
# 1    CS-97002      A      D     D+         D     B-      C      D      A
# 2    CS-97003      A      B      A        B-     B+      A     B-     B+
# 3    CS-97004      D     C+     D+         D      D     A-     D+     C-
# 4    CS-97005     A-     A-     A-        B+      A      A     A-     B+
# ..        ...    ...    ...    ...       ...    ...    ...    ...    ...
# 566  CS-97567      B      A      A        A-     A+      A     A-     A-
# 567  CS-97568     A+      A      A         A      A      A      A     A-
# 568  CS-97569      B      A     A-        B+      A      A      A      A
# 569  CS-97570      A     B+      D         A      D     D+     B-     C-
# 570  CS-97571      C      D      D         C      C     D+      B     C+
#
# ...

# %%
#changing the categorical data into numerical data 
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
for column in df.columns:
    if df[column].dtype == 'object':
        df[column] = label_encoder.fit_transform(df[column])

print(df.head())
# Out:
#    Seat No.  PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  \
# 0         0       5      10       8          6       8      10       9
# 1         1       0       9      10          9       5       6       9
# 2         2       0       3       0          5       4       0       5
# 3         3       9       7      10          9       9       2      10
# 4         4       2       2       2          4       0       0       2
#
#    EL-102  EE-119  ...  CS-312  CS-317  CS-403  CS-421  CS-406  CS-414  \
# 0       8       5  ...       8       8       8       8       2       0
# 1       0      10  ...      10       9       6       9       2       5
# 2       4       2  ...       3       3       0       6       0       0
# 3       8       9  ...      10       6      10       8       5       3
# 4       4       0  ...       5       4       4       5       2       0
#
#    CS-419  CS-423  CS-412   CGPA
# 0       8       3       2  2.205
# 1       6       6       3  2.008
# ...

# %%
df
# Out:
#      Seat No.  PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  \
# 0           0       5      10       8          6       8      10       9
# 1           1       0       9      10          9       5       6       9
# 2           2       0       3       0          5       4       0       5
# 3           3       9       7      10          9       9       2      10
# 4           4       2       2       2          4       0       0       2
# ..        ...     ...     ...     ...        ...     ...     ...     ...
# 566       566       3       0       0          2       1       0       2
# 567       567       1       0       0          0       0       0       0
# 568       568       3       0       2          4       0       0       0
# 569       569       0       4       9          0       9      10       5
# 570       570       6       9       9          6       6      10       3
#
#      EL-102  EE-119  ...  CS-312  CS-317  CS-403  CS-421  CS-406  CS-414  \
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.info
# Out:
# <bound method DataFrame.info of      Seat No.  PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  \
# 0           0       5      10       8          6       8      10       9
# 1           1       0       9      10          9       5       6       9
# 2           2       0       3       0          5       4       0       5
# 3           3       9       7      10          9       9       2      10
# 4           4       2       2       2          4       0       0       2
# ..        ...     ...     ...     ...        ...     ...     ...     ...
# 566       566       3       0       0          2       1       0       2
# 567       567       1       0       0          0       0       0       0
# 568       568       3       0       2          4       0       0       0
# 569       569       0       4       9          0       9      10       5
# 570       570       6       9       9          6       6      10       3
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 43 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Seat No.   571 non-null    int32
#  1   PH-121     571 non-null    int32
#  2   HS-101     571 non-null    int32
#  3   CY-105     571 non-null    int32
#  4   HS-105/12  571 non-null    int32
#  5   MT-111     571 non-null    int32
#  6   CS-105     571 non-null    int32
#  7   CS-106     571 non-null    int32
#  8   EL-102     571 non-null    int32
#  9   EE-119     571 non-null    int32
#  10  ME-107     571 non-null    int32
#  11  CS-107     571 non-null    int32
#  12  HS-205/20  571 non-null    int32
#  13  MT-222     571 non-null    int32
#  14  EE-222     571 non-null    int32
#  15  MT-224     571 non-null    int32
#  16  CS-210     571 non-null    int32
#  17  CS-211     571 non-null    int32
#  18  CS-203     571 non-null    int32
#  19  CS-214     571 non-null    int32
# ...

# %%
df.shape
# Out:
# (571, 43)

# %%
df.columns
# Out:
# Index(['Seat No.', 'PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111',
#        'CS-105', 'CS-106', 'EL-102', 'EE-119', 'ME-107', 'CS-107', 'HS-205/20',
#        'MT-222', 'EE-222', 'MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214',
#        'EE-217', 'CS-212', 'CS-215', 'MT-331', 'EF-303', 'HS-304', 'CS-301',
#        'CS-302', 'TC-383', 'MT-442', 'EL-332', 'CS-318', 'CS-306', 'CS-312',
#        'CS-317', 'CS-403', 'CS-421', 'CS-406', 'CS-414', 'CS-419', 'CS-423',
#        'CS-412', 'CGPA'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Seat No.     0
# PH-121       0
# HS-101       0
# CY-105       0
# HS-105/12    0
# MT-111       0
# CS-105       0
# CS-106       0
# EL-102       0
# EE-119       0
# ME-107       0
# CS-107       0
# HS-205/20    0
# MT-222       0
# EE-222       0
# MT-224       0
# CS-210       0
# CS-211       0
# CS-203       0
# CS-214       0
# EE-217       0
# CS-212       0
# CS-215       0
# MT-331       0
# EF-303       0
# HS-304       0
# CS-301       0
# CS-302       0
# TC-383       0
# MT-442       0
# EL-332       0
# CS-318       0
# CS-306       0
# CS-312       0
# CS-317       0
# CS-403       0
# CS-421       0
# CS-406       0
# CS-414       0
# CS-419       0
# CS-423       0
# CS-412       0
# CGPA         0
# dtype: int64

# %% [markdown]
# no null values are found

# %% [markdown]
# Let us Visualize using heatmap to find if the data have null values

# %%
sns.heatmap(df.isnull()) # we can cleaerly visualize that there is no null value present
# Out:
# <Axes: >

# %%
# checking the value counts of each column
for i in df.columns:
    print (df[i].value_counts())
    print('\n')
# Out:
# 0      1
# 383    1
# 377    1
# 378    1
# 379    1
#       ..
# 184    1
# 183    1
# 182    1
# 181    1
# 570    1
# Name: Seat No., Length: 571, dtype: int64
#
#
# 2     112
# 0     111
# 4      61
# 3      57
# 5      56
# 9      44
# 6      33
# 7      31
# 10     22
# 1      22
# 8      19
# 12      2
# 11      1
# Name: PH-121, dtype: int64
#
#
# 2     82
# 5     78
# 6     68
# 3     63
# 4     59
# 8     50
# 7     47
# 9     45
# 0     38
# 10    36
# 1      4
# 11     1
# Name: HS-101, dtype: int64
#
#
# 0     177
# 2     120
# 4      50
# 3      49
# 5      42
# 9      31
# 1      31
# 6      19
# 7      17
# 8      16
# 10     14
# 12      3
# 13      1
# 11      1
# Name: CY-105, dtype: int64
#
#
# 0     96
# 2     75
# 4     70
# 3     57
# 9     45
# 6     41
# 5     40
# 7     39
# 8     36
# 10    34
# 1     34
# 12     2
# 13     1
# 11     1
# Name: HS-105/12, dtype: int64
#
#
# 2     105
# 0     100
# 5      70
# 4      62
# 3      55
# 8      39
# 7      33
# ...

# %%
#Descriptive Statistics
df.describe()
# Out:
#          Seat No.      PH-121      HS-101      CY-105   HS-105/12      MT-111  \
# count  571.000000  571.000000  571.000000  571.000000  571.000000  571.000000
# mean   285.000000    3.781086    5.071804    2.921191    4.264448    3.935201
# std    164.977776    3.046895    2.785317    2.992228    3.216478    3.034481
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%    142.500000    2.000000    3.000000    0.000000    2.000000    2.000000
# 50%    285.000000    3.000000    5.000000    2.000000    4.000000    4.000000
# 75%    427.500000    6.000000    7.000000    5.000000    7.000000    6.000000
# max    570.000000   12.000000   11.000000   13.000000   13.000000   13.000000
#
#            CS-105      CS-106      EL-102      EE-119  ...      CS-312  \
# count  571.000000  571.000000  571.000000  571.000000  ...  571.000000
# mean     2.838879    4.161121    3.998249    3.921191  ...    4.299475
# ...

# %% [markdown]
# Mean is almost equal to 50% hense no skewness. there is a huge difference between 75%(Quartile3) in Almost all the columns. Hense outliers are present in all the columns

# %%
df.corr()
# Out:
#            Seat No.    PH-121    HS-101    CY-105  HS-105/12    MT-111  \
# Seat No.   1.000000  0.068592 -0.044036 -0.272158  -0.270623 -0.196181
# PH-121     0.068592  1.000000  0.382436  0.565773   0.508231  0.487830
# HS-101    -0.044036  0.382436  1.000000  0.334536   0.473146  0.441847
# CY-105    -0.272158  0.565773  0.334536  1.000000   0.516758  0.554936
# HS-105/12 -0.270623  0.508231  0.473146  0.516758   1.000000  0.505049
# MT-111    -0.196181  0.487830  0.441847  0.554936   0.505049  1.000000
# CS-105     0.000623  0.609990  0.400713  0.587845   0.493581  0.416784
# CS-106    -0.316346  0.319649  0.321346  0.404763   0.516214  0.528063
# EL-102    -0.032695  0.443420  0.359801  0.466034   0.373136  0.568940
# EE-119     0.051663  0.589250  0.323381  0.501859   0.425518  0.422151
# ME-107     0.080960  0.548820  0.345819  0.485183   0.334125  0.478874
# CS-107    -0.065632  0.501814  0.507674  0.501331   0.550732  0.503985
# ...

# %%
plt.figure(figsize=(26,14))
sns.heatmap(df.corr(),annot=True,fmt='0.2f',linewidth=0.2,linecolor='black',cmap='Spectral')
plt.xlabel('Figure',fontsize=14)
plt.ylabel('Features_Name', fontsize=14)
plt.title('Descriptive Graph',fontsize=20)
plt.show()

# %% [markdown]
# It is observed that almost all the course codes are either positvely or negatively correlated to CGPA except Seat No.

# %%
df.corr().CGPA.sort_values()
# Out:
# EL-332      -0.803475
# CS-317      -0.800771
# CS-210      -0.798841
# CS-306      -0.783624
# CS-302      -0.770868
# CS-215      -0.768707
# CS-214      -0.758407
# MT-111      -0.756109
# CS-301      -0.747775
# MT-224      -0.743577
# CS-421      -0.742041
# CS-419      -0.732899
# EE-217      -0.703131
# MT-222      -0.695418
# CS-212      -0.686163
# CS-203      -0.682817
# TC-383      -0.682447
# ME-107      -0.677342
# CY-105      -0.670190
# CS-211      -0.669814
# EL-102      -0.669536
# EE-119      -0.668787
# PH-121      -0.663135
# CS-318      -0.660106
# CS-403      -0.657128
# HS-304      -0.656729
# MT-442      -0.656557
# CS-107      -0.650531
# EE-222      -0.644384
# HS-105/12   -0.627644
# CS-423      -0.624558
# CS-105      -0.613169
# MT-331      -0.610787
# EF-303      -0.589066
# CS-106      -0.563178
# CS-312      -0.562341
# HS-101      -0.537170
# CS-414      -0.512836
# HS-205/20   -0.500668
# CS-412      -0.470128
# CS-406      -0.280626
# ...

# %% [markdown]
# Its concluded that almost all columns are highly correlated with CGPA except 2 columns

# %%
plt.figure(figsize = (22,17))
df.corr()['CGPA'].sort_values(ascending = False).drop(['CGPA']).plot(kind='bar',color='m')
plt.xlabel('Figure ',fontsize=15)
plt.ylabel('Target', fontsize=15)
plt.title('Correlation between label and features using barplot',fontsize=20)
plt.show()

# %%
#dropping column seat as it doesnt add any importance to analysis
df = df.drop('Seat No.', axis=1)

# %%
df
# Out:
#      PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  EL-102  \
# 0         5      10       8          6       8      10       9       8
# 1         0       9      10          9       5       6       9       0
# 2         0       3       0          5       4       0       5       4
# 3         9       7      10          9       9       2      10       8
# 4         2       2       2          4       0       0       2       4
# ..      ...     ...     ...        ...     ...     ...     ...     ...
# 566       3       0       0          2       1       0       2       2
# 567       1       0       0          0       0       0       0       2
# 568       3       0       2          4       0       0       0       0
# 569       0       4       9          0       9      10       5       8
# 570       6       9       9          6       6      10       3       7
#
#      EE-119  ME-107  ...  CS-312  CS-317  CS-403  CS-421  CS-406  CS-414  \
# ...

# %%
# Set the size of the figure
plt.figure(figsize=(20, 15))

# Plot a bar chart for all columns
df.plot(kind='bar', subplots=True, layout=(11, 4), figsize=(20, 60), sharex=False, sharey=False)

# Adjust layout to make room for labels
plt.tight_layout()

# Show the plot
plt.show()

# %%
#Finding distribution of dat in each column
plt.figure(figsize =(10,6), facecolor = 'green')
plotnumber = 1

for column in df:
    if plotnumber <=42:
        ax = plt.subplot(11,4,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize = 10)
        plt.yticks(rotation=0,fontsize=10)       
    plotnumber +=1
plt.tight_layout()

# %% [markdown]
# we do not see much deviation in any columns except 5 columns

# %% [markdown]
# # finding outliers

# %%
# Lets check the outliersby plotting boxplot.
plt.figure(figsize=(20,25))
p=1
for i in df:
    if p<=42:
        plt.subplot(11,4,p)
        sns.boxplot(df[i], palette = 'Set2_r')
        plt.xlabel(i)
    p+=1
plt.show()

# %% [markdown]
# we can see that some of the course codes have outliers

# %% [markdown]
# # Z-score method

# %%
#Using Z-core for the outiers removal 
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
threshold=3
np.where(z>3)
# Out:
# (array([ 44,  44,  44,  44,  44,  44,  44,  44,  60,  60,  60,  60,  60,
#          60,  86,  91,  91,  91, 137, 137, 137, 137, 137, 137, 137, 142,
#         142, 142, 142, 142, 142, 143, 143, 143, 143, 143, 143, 143, 143,
#         281, 281, 281, 281, 281, 282, 282, 288, 288, 288, 288, 288, 288,
#         288, 423, 424, 481, 543, 565, 565, 565, 565, 565, 565, 565],
#        dtype=int64),
#  array([ 2,  6, 11, 13, 15, 19, 24, 37,  2, 11, 13, 15, 24, 37, 37, 15, 24,
#         37,  2, 11, 13, 15, 19, 24, 37, 11, 13, 15, 19, 24, 37,  2, 11, 13,
#         15, 19, 24, 37, 41,  6, 11, 24, 37, 41, 24, 37, 11, 13, 15, 19, 24,
#         37, 41, 37, 37, 37, 37, 11, 13, 15, 19, 24, 37, 41], dtype=int64))

# %%
df1=df[(z<3).all(axis=1)]
df1
# Out:
#      PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  EL-102  \
# 0         5      10       8          6       8      10       9       8
# 1         0       9      10          9       5       6       9       0
# 2         0       3       0          5       4       0       5       4
# 3         9       7      10          9       9       2      10       8
# 4         2       2       2          4       0       0       2       4
# ..      ...     ...     ...        ...     ...     ...     ...     ...
# 566       3       0       0          2       1       0       2       2
# 567       1       0       0          0       0       0       0       2
# 568       3       0       2          4       0       0       0       0
# 569       0       4       9          0       9      10       5       8
# 570       6       9       9          6       6      10       3       7
#
#      EE-119  ME-107  ...  CS-312  CS-317  CS-403  CS-421  CS-406  CS-414  \
# ...

# %%
#LOSS OF DATA 
DATA_LOSS=(571-556)/556*100

# %%
'PERCENTAGE OF DATA LOST AFTER REMOVING OUTLIERS IS=',DATA_LOSS
# Out:
# ('PERCENTAGE OF DATA LOST AFTER REMOVING OUTLIERS IS=', 2.697841726618705)

# %%
df1.skew()
# Out:
# PH-121       0.561325
# HS-101       0.059312
# CY-105       0.961297
# HS-105/12    0.325083
# MT-111       0.428842
# CS-105       0.963058
# CS-106       0.610229
# EL-102       0.474081
# EE-119       0.553553
# ME-107       0.091446
# CS-107       0.393008
# HS-205/20    0.765317
# MT-222       0.167293
# EE-222       0.728173
# MT-224       0.393790
# CS-210       0.647880
# CS-211       0.075122
# CS-203       0.243867
# CS-214       0.006669
# EE-217       0.672329
# CS-212       0.401048
# CS-215       0.120711
# MT-331       0.604700
# EF-303       0.352310
# HS-304       0.515364
# CS-301       0.380912
# CS-302       0.570915
# TC-383       0.321381
# MT-442       0.852822
# EL-332       0.431139
# CS-318       0.333360
# CS-306       0.392752
# CS-312       0.402160
# CS-317       0.150608
# CS-403       0.603522
# CS-421       0.130217
# CS-406       1.214511
# CS-414       1.204268
# CS-419       0.471732
# CS-423       0.496676
# CS-412       1.189702
# ...

# %%
df1['CS-412']=np.cbrt(df1['CS-412'])

# %%
df1['CS-414']=np.cbrt(df1['CS-414'])

# %%
df1['CS-406']=np.cbrt(df1['CS-406'])

# %%
df1['CS-105']=np.cbrt(df1['CS-105'])

# %%
df1['CY-105']=np.cbrt(df1['CY-105'])

# %%
df1.skew()
# Out:
# PH-121       0.561325
# HS-101       0.059312
# CY-105      -0.394489
# HS-105/12    0.325083
# MT-111       0.428842
# CS-105      -0.566673
# CS-106       0.610229
# EL-102       0.474081
# EE-119       0.553553
# ME-107       0.091446
# CS-107       0.393008
# HS-205/20    0.765317
# MT-222       0.167293
# EE-222       0.728173
# MT-224       0.393790
# CS-210       0.647880
# CS-211       0.075122
# CS-203       0.243867
# CS-214       0.006669
# EE-217       0.672329
# CS-212       0.401048
# CS-215       0.120711
# MT-331       0.604700
# EF-303       0.352310
# HS-304       0.515364
# CS-301       0.380912
# CS-302       0.570915
# TC-383       0.321381
# MT-442       0.852822
# EL-332       0.431139
# CS-318       0.333360
# CS-306       0.392752
# CS-312       0.402160
# CS-317       0.150608
# CS-403       0.603522
# CS-421       0.130217
# CS-406      -0.674261
# CS-414      -0.442414
# CS-419       0.471732
# CS-423       0.496676
# CS-412      -0.857808
# ...

# %%
sns.distplot(df1['CS-412'], color='m', kde_kws={"shade":True}, hist=False)
plt.show()

# %%
sns.distplot(df1['CS-414'], color='m', kde_kws={"shade":True}, hist=False)
plt.show()

# %%
sns.distplot(df1['CS-406'], color='m', kde_kws={"shade":True}, hist=False)
plt.show()

# %%
sns.distplot(df1['CS-105'], color='m', kde_kws={"shade":True}, hist=False)
plt.show()

# %%
sns.distplot(df1['CY-105'], color='m', kde_kws={"shade":True}, hist=False)
plt.show()

# %% [markdown]
# # Separating Features and Label(target)

# %%
x=df1.drop("CGPA",axis=1)
y=df1["CGPA"]

# %% [markdown]
# # Feature Scaling using Standard Scalarization

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X=pd.DataFrame(sc.fit_transform(x),columns=x.columns)
X
# Out:
#        PH-121    HS-101    CY-105  HS-105/12    MT-111    CS-105    CS-106  \
# 0    0.448644  1.805855  1.261363   0.586605  1.445362  1.494460  1.849286
# 1   -1.236803  1.443772  1.464966   1.541196  0.409323  1.021766  1.849286
# 2   -1.236803 -0.728724 -1.375394   0.268407  0.063976 -1.524653  0.350994
# 3    1.797001  0.719607  1.464966   1.541196  1.790708  0.240935  2.223859
# 4   -0.562624 -1.090807  0.285659  -0.049790 -1.317410 -1.524653 -0.772725
# ..        ...       ...       ...        ...       ...       ...       ...
# 551 -0.225535 -1.814972 -1.375394  -0.686184 -0.972063 -1.524653 -0.772725
# 552 -0.899713 -1.814972 -1.375394  -1.322579 -1.317410 -1.524653 -1.521871
# 553 -0.225535 -1.814972  0.285659  -0.049790 -1.317410 -1.524653 -1.521871
# 554 -1.236803 -0.366641  1.366944  -1.322579  1.790708  1.494460  0.350994
# 555  0.785733  1.443772  1.366944   0.586605  0.754669  1.494460 -0.398152
#
# ...

# %%
y
# Out:
# 0      2.205
# 1      2.008
# 2      3.608
# 3      1.906
# 4      3.448
#        ...
# 566    3.798
# 567    3.772
# 568    3.470
# 569    2.193
# 570    1.753
# Name: CGPA, Length: 556, dtype: float64

# %%
y.value_counts()
# Out:
# 3.019    5
# 3.772    3
# 3.443    3
# 2.793    3
# 2.206    3
#         ..
# 2.253    1
# 3.844    1
# 3.882    1
# 2.555    1
# 1.753    1
# Name: CGPA, Length: 478, dtype: int64

# %% [markdown]
# Data is balanced

# %% [markdown]
# # Multicollinearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
v=variance_inflation_factor
vif=pd.DataFrame()
vif["VIF Values"]=[v(X.values,i) for i in range(len(X.columns))]
vif["Features"]=X.columns
vif
# Out:
#     VIF Values   Features
# 0     2.810268     PH-121
# 1     1.788165     HS-101
# 2     2.141026     CY-105
# 3     2.256038  HS-105/12
# 4     2.582408     MT-111
# 5     1.843936     CS-105
# 6     1.985415     CS-106
# 7     1.973637     EL-102
# 8     2.175326     EE-119
# 9     2.297721     ME-107
# 10    2.315534     CS-107
# 11    1.651358  HS-205/20
# 12    2.239296     MT-222
# 13    2.283586     EE-222
# 14    2.842965     MT-224
# 15    3.096132     CS-210
# 16    2.558970     CS-211
# 17    2.583197     CS-203
# 18    2.755645     CS-214
# 19    2.424965     EE-217
# 20    2.827549     CS-212
# 21    2.989095     CS-215
# 22    2.014221     MT-331
# 23    2.149675     EF-303
# 24    2.542513     HS-304
# 25    3.167516     CS-301
# 26    2.769431     CS-302
# 27    2.955908     TC-383
# 28    1.976113     MT-442
# 29    3.185739     EL-332
# 30    2.398169     CS-318
# 31    3.423837     CS-306
# 32    3.446658     CS-312
# 33    3.302304     CS-317
# ...

# %% [markdown]
# All vif values are less than 5 that mean there is no multicollinearity.

# %%
X.value_counts()
# Out:
# PH-121     HS-101     CY-105     HS-105/12  MT-111     CS-105     CS-106     EL-102     EE-119     ME-107     CS-107     HS-205/20  MT-222     EE-222     MT-224     CS-210     CS-211     CS-203     CS-214     EE-217     CS-212     CS-215     MT-331     EF-303     HS-304     CS-301     CS-302     TC-383     MT-442     EL-332     CS-318     CS-306     CS-312     CS-317     CS-403     CS-421     CS-406     CS-414     CS-419     CS-423     CS-412
# -1.236803  -1.814972  -1.375394  -1.322579   1.100015  -1.524653  -0.023579   0.720923   0.067033  -0.224563   0.964889   0.477766  -1.432477   0.568435  -0.072159  -0.552665   0.051058   0.876622   0.691811   0.983675  -0.919797  -0.547729   0.124706  -1.381424   0.178783  -0.792287  -1.419207  -0.047281  -0.381950   0.304548   0.373638  -0.388023  -0.321463  -0.656856  -0.163290  -0.888118   0.446514   0.353622  -1.630359   1.047126   0.063030    1
# ...

# %%
y.value_counts()
# Out:
# 3.019    5
# 3.772    3
# 3.443    3
# 2.793    3
# 2.206    3
#         ..
# 2.253    1
# 3.844    1
# 3.882    1
# 2.555    1
# 1.753    1
# Name: CGPA, Length: 478, dtype: int64

# %% [markdown]
# # Modelling or Model Buildingn and Cross_valuation Score

# %%
#Importing Libraries

# %%
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
from sklearn.ensemble import GradientBoostingRegressor,RandomForestRegressor,ExtraTreesRegressor
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor as KNN

# %%
maxAccu=0
maxRS=0
for i in range(0,100):
    x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=.20, random_state=i)
    lr=LinearRegression()
    lr.fit(x_train, y_train)
    pred = lr.predict(x_test)
    acc=r2_score(y_test, pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print('Maximum r2 score is',maxAccu,'on Random_state',maxRS)
# Out:
# Maximum r2 score is 0.9893722337642038 on Random_state 45

# %%
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=.20, random_state=45)

# %%
print('Size of x_train : ', x_train.shape)
print('Size of y_train : ', y_train.shape)
print('Size of x_test : ', x_test.shape)
print('Size of y_test : ', y_test.shape)
# Out:
# Size of x_train :  (444, 41)
# Size of y_train :  (444,)
# Size of x_test :  (112, 41)
# Size of y_test :  (112,)

# %%
LR = LinearRegression()
LR.fit(x_train,y_train)
pred_LR=LR.predict(x_test)
pred_train=LR.predict(x_train)
print('R2_score:',r2_score(y_test,pred_LR))
print('R2_score on training Data:',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:-',mean_absolute_error(y_test, pred_LR))
print('Mean Squared Error:-',mean_squared_error(y_test, pred_LR))
print('Root Mean Squared Error:-',np.sqrt(mean_squared_error(y_test, pred_LR)))
score = cross_val_score(LR,x,y, cv=5, scoring='r2')
print(score)
print(score.mean())
print('Difference between R2 score and cross validation score is =', (r2_score(y_test,pred_LR) - score.mean())*100)
# Out:
# R2_score: 0.9893722337642038
# R2_score on training Data: 98.5648916805092
# Mean Absolute Error:- 0.04989699330459114
# Mean Squared Error:- 0.003752593628626196
# Root Mean Squared Error:- 0.061258416798234315
# [0.98259422 0.98698205 0.97992003 0.98136552 0.97509576]
# 0.9811915141904329
# Difference between R2 score and cross validation score is = 0.8180719573770867

# %% [markdown]
# R2 score is 0.98 which near 1, so there is no or little error in the regression line, which is fine and difference is 0.82

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=pred_LR,y=y_test,color='r')
plt.plot(pred_LR,pred_LR,color='b')
plt.xlabel('Actual',fontsize=14)
plt.ylabel('Predicted', fontsize=14)
plt.title('Linear Regression', fontsize=18)
plt.show()

# %% [markdown]
# Actual and predicted CGPA looks completely similar. hense the model is going good

# %%
RFR=RandomForestRegressor()
RFR.fit(x_train,y_train)
pred_RFR=RFR.predict(x_test)
pred_train=RFR.predict(x_train)
print('R2_score:',r2_score(y_test,pred_RFR))
print('R2_score on training Data:',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:-',mean_absolute_error(y_test, pred_RFR))
print('Mean Squared Error:-',mean_squared_error(y_test, pred_RFR))
print('Root Mean Squared Error:-',np.sqrt(mean_squared_error(y_test, pred_RFR)))
score1 = cross_val_score(RFR,x,y)
print(score1)
print(score1.mean())
print('Difference between R2 score and cross validation score is – ', (r2_score(y_test,pred_RFR) - score1.mean())*100)
# Out:
# R2_score: 0.9507162712041455
# R2_score on training Data: 99.27999768998797
# Mean Absolute Error:- 0.09939330357142843
# Mean Squared Error:- 0.017401757111607095
# Root Mean Squared Error:- 0.13191571972895078
# [0.94881323 0.95368347 0.95424844 0.94236396 0.92732485]
# 0.9452867896113899
# Difference between R2 score and cross validation score is –  0.5429481592755581

# %% [markdown]
# R2 score is 0.95 which near 1, so there is no or little error in the regression line, which is fine and difference is 0.54

# %%
knn=KNN()
knn.fit(x_train,y_train)
pred_knn=knn.predict(x_test)
pred_train=knn.predict(x_train)
print('R2_score:',r2_score(y_test,pred_knn))
print('R2_score on training Data:',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:-',mean_absolute_error(y_test, pred_knn))
print('Mean Squared Error:-',mean_squared_error(y_test, pred_knn))
print('Root Mean Squared Error:-',np.sqrt(mean_squared_error(y_test, pred_knn)))
score2 = cross_val_score(knn,x,y)
print(score2)
print(score2.mean())
print('Difference between R2 score and cross validation score is =', (r2_score(y_test,pred_knn) - score2.mean())*100)
# Out:
# R2_score: 0.9702958917596118
# R2_score on training Data: 97.58208258627941
# Mean Absolute Error:- 0.07649821428571431
# Mean Squared Error:- 0.010488323214285718
# Root Mean Squared Error:- 0.10241251492999144
# [0.97499933 0.96709674 0.96103492 0.95399806 0.94168066]
# 0.959761942579904
# Difference between R2 score and cross validation score is = 1.0533949179707847

# %% [markdown]
# R2 score is 0.97 which near 1, so there is no or little error in the regression line, which is fine and difference is 1.05

# %%
GBR=GradientBoostingRegressor()
GBR.fit(x_train,y_train)
pred_GBR=GBR.predict(x_test)
pred_train=GBR.predict(x_train)
print('R2_score:',r2_score(y_test,pred_GBR))
print('R2_score on training Data:',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:-',mean_absolute_error(y_test, pred_GBR))
print('Mean Squared Error:-',mean_squared_error(y_test, pred_GBR))
print('Root Mean Squared Error:-',np.sqrt(mean_squared_error(y_test, pred_GBR)))
score3 = cross_val_score(GBR,x,y)
print(score3)
print(score3.mean())
print('Difference between R2 score and cross validation score is –', (r2_score(y_test,pred_GBR) - score3.mean())*100)
# Out:
# R2_score: 0.9670420344227293
# R2_score on training Data: 99.70578542592379
# Mean Absolute Error:- 0.0851071032425739
# Mean Squared Error:- 0.01163723861569123
# Root Mean Squared Error:- 0.10787603355561062
# [0.95466168 0.96675039 0.96738873 0.96768068 0.95784933]
# 0.9628661631437234
# Difference between R2 score and cross validation score is – 0.41758712790058716

# %% [markdown]
# R2 score is 0.97 which near 1, so there is no or little error in the regression line, which is fine and difference is 0.42

# %%
lasso=Lasso()
lasso.fit(x_train,y_train)
pred_lasso=lasso.predict(x_test)
pred_train=lasso.predict(x_train)
print('R2_score:',r2_score(y_test,pred_lasso))
print('R2_score on training Data:',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:-',mean_absolute_error(y_test, pred_lasso))
print('Mean Squared Error:-',mean_squared_error(y_test, pred_lasso))
print('Root Mean Squared Error:-',np.sqrt(mean_squared_error(y_test, pred_lasso)))
score4 = cross_val_score(lasso,x,y)
print(score4)
print(score4.mean())
print('Difference between R2 score and cross validation score is – ', (r2_score(y_test,pred_lasso) - score4.mean())*100)
# Out:
# R2_score: -0.0023040983717981245
# R2_score on training Data: 0.0
# Mean Absolute Error:- 0.5012554697554698
# Mean Squared Error:- 0.35390691609563224
# Root Mean Squared Error:- 0.5949007615524057
# [0.35845112 0.32991325 0.34218644 0.34443748 0.30608807]
# 0.33621527079390123
# Difference between R2 score and cross validation score is –  -33.85193691656993

# %% [markdown]
# This model is not at all a fit model as the score is -0.0023

# %%
rd=Ridge()
rd.fit(x_train,y_train)
pred_rd=rd.predict(x_test)
pred_train=rd.predict(x_train)
print('R2_score:',r2_score(y_test,pred_rd))
print('R2_score on training Data:',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:-',mean_absolute_error(y_test, pred_rd))
print('Mean Squared Error:-',mean_squared_error(y_test, pred_rd))
print('Root Mean Squared Error:-',np.sqrt(mean_squared_error(y_test, pred_rd)))
score5 = cross_val_score(rd,x,y)
print(score5)
print(score5.mean())
print('Difference between R2 score and cross validation score is – ', (r2_score(y_test,pred_rd) - score5.mean())*100)
# Out:
# R2_score: 0.9893970989179113
# R2_score on training Data: 98.56487973687263
# Mean Absolute Error:- 0.049846609313235875
# Mean Squared Error:- 0.0037438139080990976
# Root Mean Squared Error:- 0.06118671349320126
# [0.98258006 0.98699932 0.97994597 0.98135711 0.97507632]
# 0.9811917554599591
# Difference between R2 score and cross validation score is –  0.8205343457952208

# %% [markdown]
# R2 score is 0.98 which near 1, so there is no or little error in the regression line, which is fine and difference is 0.82

# %%
dt= DecisionTreeRegressor()
dt.fit(x_train,y_train)
pred_dt=dt.predict(x_test)
pred_train=dt.predict(x_train)
print('R2_score:',r2_score(y_test,pred_dt))
print('R2_score on training Data:',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:-',mean_absolute_error(y_test, pred_dt))
print('Mean Squared Error:-',mean_squared_error(y_test, pred_dt))
print('Root Mean Squared Error:-',np.sqrt(mean_squared_error(y_test, pred_dt)))
score6 = cross_val_score(dt,x,y)
print(score6)
print(score6.mean())
print('Difference between R2 score and cross validation score is – ', (r2_score(y_test,pred_dt) - score6.mean())*100)
# Out:
# R2_score: 0.854387330009949
# R2_score on training Data: 100.0
# Mean Absolute Error:- 0.17131249999999998
# Mean Squared Error:- 0.05141486607142857
# Root Mean Squared Error:- 0.22674846431989032
# [0.83820096 0.84619479 0.7712819  0.78751415 0.79248878]
# 0.8071361165296798
# Difference between R2 score and cross validation score is –  4.725121348026928

# %% [markdown]
# R2 score is 0.85 which near 1, so there is no or little error in the regression line, which is fine and difference is 4.73

# %%
svr= SVR()
svr.fit(x_train,y_train)
pred_svr=svr.predict(x_test)
pred_train=svr.predict(x_train)
print('R2_score:',r2_score(y_test,pred_svr))
print('R2_score on training Data:',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:-',mean_absolute_error(y_test, pred_svr))
print('Mean Squared Error:-',mean_squared_error(y_test, pred_svr))
print('Root Mean Squared Error:-',np.sqrt(mean_squared_error(y_test, pred_svr)))
score7 = cross_val_score(svr,x,y)
print(score7)
print(score7.mean())
print('Difference between R2 score and cross validation score is – ', (r2_score(y_test,pred_svr) - score7.mean())*100)
# Out:
# R2_score: 0.9686971648229806
# R2_score on training Data: 98.6603905752767
# Mean Absolute Error:- 0.08470574190926172
# Mean Squared Error:- 0.01105282307090735
# Root Mean Squared Error:- 0.10513240732955442
# [0.96131213 0.97002137 0.97334254 0.96314296 0.96355532]
# 0.9662748628534743
# Difference between R2 score and cross validation score is –  0.24223019695063241

# %% [markdown]
# R2 score is 0.97 which near 1, so there is no or little error in the regression line, which is fine and difference is 0.24

# %%
etr=ExtraTreesRegressor()
etr.fit(x_train,y_train)
pred_etr=etr.predict(x_test)
pred_train=etr.predict(x_train)
print('R2_score:',r2_score(y_test,pred_etr))
print('R2_score on training Data:',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:-',mean_absolute_error(y_test, pred_etr))
print('Mean Squared Error:-',mean_squared_error(y_test, pred_etr))
print('Root Mean Squared Error:-',np.sqrt(mean_squared_error(y_test, pred_etr)))
score8 = cross_val_score(etr,x,y)
print(score8)
print(score8.mean())
print('Difference between R2 score and cross validation score is – ', (r2_score(y_test,pred_etr) - score8.mean())*100)
# Out:
# R2_score: 0.9696152206618329
# R2_score on training Data: 100.0
# Mean Absolute Error:- 0.07728750000000008
# Mean Squared Error:- 0.010728663655357134
# Root Mean Squared Error:- 0.10357926267046476
# [0.96494444 0.96104219 0.95969768 0.95915712 0.95100671]
# 0.9591696285584448
# Difference between R2 score and cross validation score is –  1.0445592103388135

# %% [markdown]
# R2 score is 0.97 which near 1, so there is no or little error in the regression line, which is fine and difference is 1.044

# %%
model = [('Linear Regression', r2_score(y_test,pred_LR),np.sqrt(mean_squared_error(y_test, pred_LR)),score.mean()),
          ('Random Forest Regressor',r2_score(y_test,pred_RFR),np.sqrt(mean_squared_error(y_test, pred_RFR)),score1.mean()),
          ('KNN',r2_score(y_test,pred_knn),np.sqrt(mean_squared_error(y_test, pred_knn)),score2.mean()),
          ('GradientBoostingRegressor',r2_score(y_test,pred_GBR),np.sqrt(mean_squared_error(y_test, pred_GBR)),score3.mean()),
         ('Lasso',r2_score(y_test,pred_lasso),np.sqrt(mean_squared_error(y_test, pred_lasso)),score4.mean()),
         ('Ridge',r2_score(y_test,pred_rd),np.sqrt(mean_squared_error(y_test, pred_rd)),score5.mean()),
         ('DecisionTreeRegressor',r2_score(y_test,pred_dt),np.sqrt(mean_squared_error(y_test, pred_dt)),score6.mean()),
         ('SVR',r2_score(y_test,pred_svr),np.sqrt(mean_squared_error(y_test, pred_svr)),score7.mean()),
         ('ExtraTreesRegressor',r2_score(y_test,pred_etr),np.sqrt(mean_squared_error(y_test, pred_etr)),score8.mean())
        ]

# %%
Model = pd.DataFrame(data = model, columns=['Model','R2_Score(test)','RMSE', 'Cross-Validation'])
Model
# Out:
#                        Model  R2_Score(test)      RMSE  Cross-Validation
# 0          Linear Regression        0.989372  0.061258          0.981192
# 1    Random Forest Regressor        0.950716  0.131916          0.945287
# 2                        KNN        0.970296  0.102413          0.959762
# 3  GradientBoostingRegressor        0.967042  0.107876          0.962866
# 4                      Lasso       -0.002304  0.594901          0.336215
# 5                      Ridge        0.989397  0.061187          0.981192
# 6      DecisionTreeRegressor        0.854387  0.226748          0.807136
# 7                        SVR        0.968697  0.105132          0.966275
# 8        ExtraTreesRegressor        0.969615  0.103579          0.959170

# %% [markdown]
# From the above observation , it can be concluded that Ridge and Linear Regression is the best Model having r2_score as 0.989 and CV as 0.981. so the difference is 0.81. Choosing Ridge as the final Model.

# %% [markdown]
# # Hyper Parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV
param={'alpha':[1.0,.05,.4,2],'fit_intercept':[True,False],
'solver':['auto', 'svd', 'cholesky', 'lsqr', 'sag', 'saga', 'lbfgs' ],
'positive':[False,True],
'random_state':[1,4,10,20]
      
}
Gscv=GridSearchCV(Ridge(),param,cv=5)
Gscv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [1.0, 0.05, 0.4, 2],
#                          'fit_intercept': [True, False],
#                          'positive': [False, True],
#                          'random_state': [1, 4, 10, 20],
#                          'solver': ['auto', 'svd', 'cholesky', 'lsqr', 'sag',
#                                     'saga', 'lbfgs']})

# %%
Gscv.best_params_
# Out:
# {'alpha': 2,
#  'fit_intercept': True,
#  'positive': False,
#  'random_state': 1,
#  'solver': 'lsqr'}

# %%
Model=Ridge(alpha=2,fit_intercept= True,positive=False,random_state= 1,solver= 'lsqr')
Model.fit(x_train,y_train)
pred=Model.predict(x_test)
print('R2_score:',r2_score(y_test,pred))
print('Mean Absolute Error:-',mean_absolute_error(y_test, pred))
print('Mean Squared Error:-',mean_squared_error(y_test, pred))
print('Root Mean Squared Error:-',np.sqrt(mean_squared_error(y_test, pred)))
# Out:
# R2_score: 0.9894209435321976
# Mean Absolute Error:- 0.049788426213713335
# Mean Squared Error:- 0.0037353945332594045
# Root Mean Squared Error:- 0.06111787408982257

# %%
#Saving the Model
import pickle
filename='Students_Grade_Prediction.pkl'
pickle.dump(Model, open(filename, 'wb')) #saved model

# %%
import pickle
loaded_model =pickle.load(open('Students_Grade_Prediction.pkl','rb'))
result=loaded_model.score(x_test,y_test)

# %%
print(result*100)
# Out:
# 98.94209435321976

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],y_test[:]],index=['Predicted','Original'])
conclusion
# Out:
#                 0         1        2         3         4         5    \
# Predicted  3.036675  3.400587  2.59867  1.766748  2.373361  3.207644
# Original   3.060000  3.325000  2.65900  1.714000  2.384000  3.335000
#
#                 6         7       8         9    ...       102       103  \
# Predicted  2.697201  1.920873  2.8431  3.067998  ...  2.759323  2.833206
# Original   2.698000  1.845000  2.7560  3.090000  ...  2.791000  2.895000
#
#                 104      105       106      107       108       109       110  \
# Predicted  3.713634  1.94862  3.020086  2.38666  3.214242  3.586087  3.731866
# Original   3.700000  1.91900  3.075000  2.39400  3.193000  3.615000  3.727000
#
#                 111
# Predicted  3.501025
# Original   3.554000
#
# [2 rows x 112 columns]
